# %% [markdown]
# # Replicating Sugihara et al. (2012) — *Detecting Causality in Complex Ecosystems*
# ### Figures 3 (A–E), 4 (B–C), and 5 (C–F)
#
# **Reference:** Sugihara G, May R, Ye H, Hsieh C-H, Deyle E, Fogarty M, Munch S (2012).
# Detecting causality in complex ecosystems. *Science* **338**(6106): 496–500.
# DOI: [10.1126/science.1227079](https://doi.org/10.1126/science.1227079)
#
# ---
#
# ### The core idea: Convergent Cross Mapping (CCM)
#
# In nonlinear dynamical systems, if variable Y causally influences variable X, then
# Y's history leaves a detectable signature in X's attractor manifold.
# CCM exploits this via Takens' embedding theorem:
#
# 1. **Embed** X into a shadow manifold $M_X$ using lagged coordinates $\mathbf{x}(t) = [X(t), X(t-\tau), \ldots, X(t-(E-1)\tau)]$
# 2. Draw a random **library** of $L$ points from $M_X$
# 3. For each library point, use its $E+1$ nearest neighbours (leave-one-out) to **predict** Y at the same time index
# 4. Compute Pearson $\rho$ between predictions and actual Y values
# 5. **Convergence** ($\rho$ increases with $L$) means Y causally influences X
#
# **Notation:** "$A$ xmap $B$" = use $A$'s manifold to predict $B$.
# If this converges → **$B$ causally influences $A$**.

# %% [markdown]
# ## 0 · Imports and shared utilities

# %%
import gzip, struct
import numpy as np
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import MultipleLocator
from mpl_toolkits.mplot3d import Axes3D

# ── Coupled logistic map (Eq. 1 in the paper) ────────────────────────────────
# X(t+1) = X(t) [r_x - r_x X(t) - β_xy Y(t)]
# Y(t+1) = Y(t) [r_y - r_y Y(t) - β_yx X(t)]
def coupled_logistic(N, beta_xy, beta_yx, rx=3.8, ry=3.5, warmup=500, seed=42):
    """Generate N time steps of the coupled logistic map (Eq. 1).
    
    Parameters: rx=3.8, ry=3.5 produce chaotic dynamics.
    warmup: transient steps discarded to reach attractor.
    """
    rng = np.random.default_rng(seed)
    X = np.zeros(N + warmup)
    Y = np.zeros(N + warmup)
    X[0], Y[0] = rng.random(), rng.random()
    for t in range(N + warmup - 1):
        X[t+1] = np.clip(X[t] * (rx - rx*X[t] - beta_xy*Y[t]), 0, None)
        Y[t+1] = np.clip(Y[t] * (ry - ry*Y[t] - beta_yx*X[t]), 0, None)
    return X[warmup:], Y[warmup:]


# ── Core CCM algorithm ────────────────────────────────────────────────────────
def ccm_rho(lib_ts, target_ts, E=2, tau=1, L=None, seed=42):
    """Convergent Cross Mapping — single cross-map skill estimate.

    Builds shadow manifold M from lib_ts with time-delay embedding.
    Draws L random library points. For each, predicts target_ts at the
    same time index using E+1 leave-one-out nearest neighbours.

    Returns Pearson rho of predictions vs. actual target values.
    Convergence (rho increases with L) → target causally influences lib.
    """
    rng     = np.random.default_rng(seed)
    n       = len(lib_ts)
    n_embed = n - (E - 1) * tau

    # Shadow manifold: row i ↔ time i + (E-1)*tau
    M = np.array([[lib_ts[i + (E-1)*tau - j*tau] for j in range(E)]
                  for i in range(n_embed)])
    Y_target = target_ts[(E-1)*tau : (E-1)*tau + n_embed]

    if L is None or L >= n_embed:
        L = n_embed
    L = int(L)

    lib_idx = rng.choice(n_embed, size=L, replace=False)
    M_lib   = M[lib_idx]
    Y_lib   = Y_target[lib_idx]

    Y_pred = np.full(L, np.nan)
    for k in range(L):
        dists    = np.sqrt(np.sum((M_lib - M_lib[k]) ** 2, axis=1))
        dists[k] = np.inf                       # leave-one-out
        nn       = np.argsort(dists)[: E + 1]
        dw       = dists[nn]
        if dw[0] == np.inf:
            continue
        w        = np.exp(-dw / (dw[0] + 1e-12))
        w       /= w.sum()
        Y_pred[k] = np.dot(w, Y_lib[nn])

    valid = ~np.isnan(Y_pred)
    if valid.sum() < 3:
        return np.nan
    return pearsonr(Y_lib[valid], Y_pred[valid])[0]


def ccm_curve(lib_ts, tgt_ts, L_vals, n_reps=100, E=2, base_seed=0):
    """Mean CCM rho across n_reps draws for each L in L_vals."""
    out = []
    for L in L_vals:
        rhos  = [ccm_rho(lib_ts, tgt_ts, E=E, L=int(L),
                         seed=base_seed + int(L)*100 + s)
                 for s in range(n_reps)]
        valid = [r for r in rhos if not np.isnan(r)]
        out.append(np.mean(valid) if valid else np.nan)
    return np.array(out)


print("Utilities defined. E=2, τ=1 for model figures; E=3, τ=1 for ecological data.")
# Out:
# Utilities defined. E=2, τ=1 for model figures; E=3, τ=1 for ecological data.

# %% [markdown]
# ---
# ## Figure 3 — Detecting Causation with CCM
#
# **Model:** Coupled logistic map (Eq. 1), $r_x = 3.8$, $r_y = 3.5$, producing chaotic dynamics.
# All panels use **E = 2, τ = 1**.
#
# ### 3A · CCM convergence curves — bidirectional coupling
#
# **Setup:** $\beta_{xy} = 0.02$, $\beta_{yx} = 0.1$ → X has stronger effect on Y than vice versa.
#
# **Reading:**
# - $\hat{X}(t)|M_Y$ (blue): use Y's manifold to predict X. Higher because $\beta_{yx}$ is larger (Y retains more info about X).
# - $\hat{Y}(t)|M_X$ (red): use X's manifold to predict Y. Lower because $\beta_{xy}$ is smaller.
# - Both lines **converge** (rise with $L$) → bidirectional causation confirmed.

# %%
# Fig 3A: N=3000, β_xy=0.02, β_yx=0.1
N_3A   = 3000
X_3A, Y_3A = coupled_logistic(N_3A, beta_xy=0.02, beta_yx=0.1)

L_3A = np.array([100, 200, 400, 700, 1000, 1500, 2000, 2500, 3000])

print("Computing Fig 3A convergence curves…")
r_Xhat_MY = ccm_curve(Y_3A, X_3A, L_3A, n_reps=100, E=2, base_seed=0)   # X̂|M_Y (blue)
r_Yhat_MX = ccm_curve(X_3A, Y_3A, L_3A, n_reps=100, E=2, base_seed=1)   # Ŷ|M_X (red)

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(L_3A, r_Xhat_MY, 'b-', lw=2.2, label=r'$\hat{X}(t)|M_Y$  (β$_{y,x}$=0.1, converges faster)')
ax.plot(L_3A, r_Yhat_MX, 'r-', lw=2.2, label=r'$\hat{Y}(t)|M_X$  (β$_{x,y}$=0.02, converges slower)')
ax.set_xlabel('Library size  $L$', fontsize=12)
ax.set_ylabel(r'Cross-map skill  $\rho$', fontsize=12)
ax.set_ylim(0, 1.05)
ax.set_xlim(0, N_3A)
ax.xaxis.set_major_locator(MultipleLocator(500))
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.legend(fontsize=9, frameon=True)
ax.set_title('Fig. 3A — CCM convergence, bidirectional coupling\n'
             r'β$_{xy}$=0.02, β$_{yx}$=0.1  →  Y has stronger effect on X',
             fontsize=10)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()
print(f"At L={N_3A}: X̂|M_Y rho={r_Xhat_MY[-1]:.3f}, Ŷ|M_X rho={r_Yhat_MX[-1]:.3f}")
print("Blue > red because β_yx > β_xy ✓")
# Out:
# Computing Fig 3A convergence curves…
# At L=3000: X̂|M_Y rho=0.991, Ŷ|M_X rho=0.927
# Blue > red because β_yx > β_xy ✓

# %% [markdown]
# ### 3B · Contour map — asymmetry of cross-map skill
#
# **Setup:** $N = L = 400$. Both $\beta_{xy}$ and $\beta_{yx}$ varied on a grid from 0 to 0.4.
#
# **Color:** $\rho(\hat{Y}|M_x) - \rho(\hat{X}|M_Y)$
# - **Positive (warm):** X has stronger effect on Y → Ŷ|M_X better
# - **Negative (cool):** Y has stronger effect on X → X̂|M_Y better
# - **Near zero (white):** symmetric coupling
#
# The off-diagonal pattern confirms that relative cross-map skill tracks *relative coupling strength*.

# %%
# Fig 3B: 22×22 grid of β values, N=L=400
print("Computing Fig 3B contour grid (22×22, ~5 min)…")
betas   = np.linspace(0, 0.4, 22)
N_3B    = 400
rho_diff = np.zeros((len(betas), len(betas)))

for i, b_yx in enumerate(betas):
    for j, b_xy in enumerate(betas):
        X, Y = coupled_logistic(N_3B, b_xy, b_yx, warmup=200)
        r_yx = np.nanmean([ccm_rho(X, Y, E=2, L=380, seed=s)      for s in range(20)])  # Ŷ|Mx
        r_xy = np.nanmean([ccm_rho(Y, X, E=2, L=380, seed=s+100)  for s in range(20)])  # X̂|MY
        rho_diff[i, j] = r_yx - r_xy   # positive when X→Y is stronger

fig, ax = plt.subplots(figsize=(5.5, 5))
BX, BY  = np.meshgrid(betas, betas)
lvls    = np.linspace(-0.8, 0.8, 17)
cf = ax.contourf(BX, BY, rho_diff, levels=lvls, cmap='RdBu_r')
ax.contour(BX, BY, rho_diff, levels=lvls, colors='k', linewidths=0.3, alpha=0.4)
cb = plt.colorbar(cf, ax=ax, shrink=0.9)
cb.set_label(r'$\rho(\hat{Y}|M_x) - \rho(\hat{X}|M_Y)$', fontsize=9)
cb.ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.set_xlabel(r'$\beta_{x,y}$  (effect of Y on X)', fontsize=11)
ax.set_ylabel(r'$\beta_{y,x}$  (effect of X on Y)', fontsize=11)
ax.xaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.set_title('Fig. 3B — Asymmetry of cross-map skill\n'
             'Warm = X→Y dominates; Cool = Y→X dominates', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Computing Fig 3B contour grid (22×22, ~5 min)…

# %% [markdown]
# ### 3C & 3D · Scatter plots — unidirectional coupling ($\beta_{xy} = 0$)
#
# **Setup:** $\beta_{xy} = 0$ (Y has **no effect** on X), $\beta_{yx} = 0.1$, $N = L = 400$.
#
# - **3C (red):** $\hat{Y}$ estimated from $M_X$ vs. $Y$ observed.
#   Cross-map *fails* — X's manifold contains no information about Y because Y doesn't drive X.
# - **3D (blue):** $\hat{X}$ estimated from $M_Y$ vs. $X$ observed.
#   Cross-map *succeeds* — Y's manifold encodes X's history because X drives Y.

# %%
# Fig 3C & 3D: β_xy=0, β_yx=0.1, N=400, full library (L=N)
E2, TAU1 = 2, 1
N_3CD = 400
X_3CD, Y_3CD = coupled_logistic(N_3CD, beta_xy=0.0, beta_yx=0.1, warmup=200)

ne = N_3CD - (E2 - 1) * TAU1
M_X = np.array([[X_3CD[i + TAU1 - j*TAU1] for j in range(E2)] for i in range(ne)])
M_Y = np.array([[Y_3CD[i + TAU1 - j*TAU1] for j in range(E2)] for i in range(ne)])
X_tgt = X_3CD[TAU1 : TAU1 + ne]
Y_tgt = Y_3CD[TAU1 : TAU1 + ne]

def predict_loo(M_lib, Y_lib, E=2):
    """Full-library leave-one-out predictions."""
    n = M_lib.shape[0]
    Yp = np.full(n, np.nan)
    for k in range(n):
        d = np.sqrt(np.sum((M_lib - M_lib[k]) ** 2, axis=1))
        d[k] = np.inf
        nn = np.argsort(d)[: E + 1]
        dw = d[nn]
        if dw[0] == np.inf:
            continue
        w  = np.exp(-dw / (dw[0] + 1e-12))
        w /= w.sum()
        Yp[k] = np.dot(w, Y_lib[nn])
    return Yp

Y_hat_from_MX = predict_loo(M_X, Y_tgt, E2)   # Panel C: should FAIL
X_hat_from_MY = predict_loo(M_Y, X_tgt, E2)   # Panel D: should SUCCEED

rho_C = pearsonr(Y_tgt[~np.isnan(Y_hat_from_MX)], Y_hat_from_MX[~np.isnan(Y_hat_from_MX)])[0]
rho_D = pearsonr(X_tgt[~np.isnan(X_hat_from_MY)], X_hat_from_MY[~np.isnan(X_hat_from_MY)])[0]

fig, axes = plt.subplots(1, 2, figsize=(10, 4.5))

# Panel C
ax = axes[0]
v = ~np.isnan(Y_hat_from_MX)
ax.scatter(Y_tgt[v], Y_hat_from_MX[v], c='red', s=6, alpha=0.5, rasterized=True)
ax.plot([0, 1], [0, 1], 'k--', lw=1, alpha=0.6)
ax.set_xlabel('$Y(t)$ observed', fontsize=11)
ax.set_ylabel(r'$\hat{Y}(t)|M_X$ estimated', fontsize=11)
ax.set_title(f'Fig. 3C — Cross-map FAILS  (β$_{{xy}}$=0)\n'
             f'Ŷ from M_X:  ρ = {rho_C:.3f}', fontsize=10)
ax.set_xlim(0, 1); ax.set_ylim(0, 1)
ax.text(0.05, 0.93, 'β$_{xy}$ = 0\n→ no Y info in M_X', transform=ax.transAxes,
        fontsize=9, color='red', va='top')

# Panel D
ax = axes[1]
v = ~np.isnan(X_hat_from_MY)
ax.scatter(X_tgt[v], X_hat_from_MY[v], c='blue', s=6, alpha=0.5, rasterized=True)
ax.plot([0, 1], [0, 1], 'k--', lw=1, alpha=0.6)
ax.set_xlabel('$X(t)$ observed', fontsize=11)
ax.set_ylabel(r'$\hat{X}(t)|M_Y$ estimated', fontsize=11)
ax.set_title(f'Fig. 3D — Cross-map SUCCEEDS  (β$_{{yx}}$=0.1)\n'
             f'X̂ from M_Y:  ρ = {rho_D:.3f}', fontsize=10)
ax.set_xlim(0, 1); ax.set_ylim(0, 1)
ax.text(0.05, 0.93, 'β$_{yx}$ = 0.1\n→ X info encoded in M_Y', transform=ax.transAxes,
        fontsize=9, color='blue', va='top')

fig.suptitle('Unidirectional coupling: X drives Y, Y does not drive X', fontsize=11)
plt.tight_layout()
plt.show()
print(f"Panel C rho={rho_C:.3f} (expected ~0)  |  Panel D rho={rho_D:.3f} (expected ~0.9)")
# Out:
# Panel C rho=-0.122 (expected ~0)  |  Panel D rho=0.935 (expected ~0.9)

# %% [markdown]
# ### 3E · 3D surface — non-convergence under unidirectional forcing
#
# **Setup:** $\beta_{xy} = 0$ fixed. $\beta_{yx}$ varies from 0 to 2.0. $L$ varies from 100 to 2000.
# **Z-axis:** $\rho(\hat{Y}(t)|M_X)$ — cross-map skill when trying to predict Y from X's manifold.
#
# **Key result:** With $\beta_{xy} = 0$, X's manifold contains *no information* about Y,
# so cross-map skill stays low for most parameter values — it does **not converge** with $L$.
# The exception is at very high $\beta_{yx}$ where the system synchronises (dimensionality collapse),
# creating the red plateau at the back of the surface.

# %%
# Fig 3E: 3D surface — β_xy=0, vary β_yx (0→2) and L (100→2000)
print("Computing Fig 3E 3D surface (14×14 grid)…")
b_yx_vals = np.linspace(0, 2.0, 14)
L_3E_vals = np.array([100, 250, 400, 600, 800, 1000, 1300, 1600, 2000])
rho_3E    = np.zeros((len(L_3E_vals), len(b_yx_vals)))

N_3E = 2200
for j, byx in enumerate(b_yx_vals):
    X, Y = coupled_logistic(N_3E, beta_xy=0.0, beta_yx=byx)
    for i, L in enumerate(L_3E_vals):
        rho_3E[i, j] = np.nanmean([ccm_rho(X, Y, E=2, L=int(L), seed=s)
                                    for s in range(10)])

rho_3E = np.clip(rho_3E, 0, 1)    # clip negatives for display (absent skill = 0)

BV_3E, LV_3E = np.meshgrid(b_yx_vals, L_3E_vals)

fig = plt.figure(figsize=(9, 6))
ax3 = fig.add_subplot(111, projection='3d')
surf = ax3.plot_surface(LV_3E, BV_3E, rho_3E, cmap='jet',
                         edgecolor='k', linewidth=0.2, antialiased=True)
cb = fig.colorbar(surf, ax=ax3, shrink=0.5, pad=0.1)
cb.set_label(r'$\rho(\hat{Y}(t)|M_x)$', fontsize=10)
cb.ax.yaxis.set_major_locator(MultipleLocator(0.2))

ax3.set_xlabel('$L$', fontsize=11, labelpad=8)
ax3.set_ylabel(r'$\beta_{y,x}$', fontsize=11, labelpad=8)
ax3.set_zlabel(r'$\rho(\hat{Y}|M_x)$', fontsize=9, labelpad=6)
ax3.set_xlim(2000, 100)
ax3.set_ylim(0, 2)
ax3.set_zlim(0, 1.0)
ax3.view_init(elev=22, azim=-50)
ax3.set_title('Fig. 3E — No convergence when β$_{x,y}$=0\n'
              'Plateau at high β$_{y,x}$ = synchrony (dimensionality collapse)', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Computing Fig 3E 3D surface (14×14 grid)…

# %% [markdown]
# ---
# ## Figure 4 — Model Causal Networks
#
# ### 4B · External forcing of non-coupled variables
#
# **Model:** Z drives both X and Y independently; X and Y do NOT interact.
#
# $$Z(t+1) = Z(t)[r_Z - r_Z Z(t)]$$
# $$X(t+1) = X(t)[r_X - r_X X(t) - \beta_{XZ} Z(t)]$$
# $$Y(t+1) = Y(t)[r_Y - r_Y Y(t) - \beta_{YZ} Z(t)]$$
#
# **Key result:** Cross-correlation (dashed) is misleadingly high (~0.4), suggesting X and Y
# interact. CCM xmap lines are flat — **no convergence** — correctly showing no direct coupling.

# %%
# Fig 4B: external forcing example
# Z→X and Z→Y, but X and Y don't interact directly
np.random.seed(42)
N_4B   = 1000
rz, rx, ry = 3.8, 3.65, 3.77
beta_XZ = beta_YZ = 0.5

Z_4B = np.zeros(N_4B); Z_4B[0] = 0.5
for t in range(N_4B - 1):
    Z_4B[t+1] = Z_4B[t] * (rz - rz * Z_4B[t])

X_4B = np.zeros(N_4B); Y_4B = np.zeros(N_4B)
X_4B[0], Y_4B[0] = 0.2, 0.4
for t in range(N_4B - 1):
    X_4B[t+1] = np.clip(X_4B[t] * (rx - rx*X_4B[t] - beta_XZ*Z_4B[t]), 0, None)
    Y_4B[t+1] = np.clip(Y_4B[t] * (ry - ry*Y_4B[t] - beta_YZ*Z_4B[t]), 0, None)

L_4B  = np.arange(20, 161, 10)
N_REPS = 50

print("Computing Fig 4B CCM curves…")
r_XxmapY = ccm_curve(X_4B, Y_4B, L_4B, n_reps=N_REPS, E=2, base_seed=0)
r_YxmapX = ccm_curve(Y_4B, X_4B, L_4B, n_reps=N_REPS, E=2, base_seed=1)

# Rolling Pearson cross-correlation for comparison
roll_cc = np.array([np.corrcoef(X_4B[:int(L)], Y_4B[:int(L)])[0,1] for L in L_4B])

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(L_4B, roll_cc,   'k--', lw=2,   label='Cross-correlation')
ax.plot(L_4B, r_XxmapY, 'b-',  lw=2.2, label='$X$ xmap $Y$')
ax.plot(L_4B, r_YxmapX, 'g-',  lw=2.2, label='$Y$ xmap $X$')
ax.axhline(0, color='k', lw=0.7, ls=':', alpha=0.6)
ax.set_xlabel('Library size  $L$', fontsize=12)
ax.set_ylabel(r'$\rho$', fontsize=13)
ax.set_xlim(L_4B[0], L_4B[-1])
ax.set_ylim(-0.1, 1.0)
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.legend(fontsize=10, frameon=True)
ax.set_title('Fig. 4B — External forcing: Z→X and Z→Y independently\n'
             'Cross-correlation is misleadingly high; CCM shows no convergence',
             fontsize=10)
ax.grid(alpha=0.3)

# Annotate the key comparison
ax.annotate('Cross-correlation\nsuggests interaction\n(but X, Y don\'t interact!)',
            xy=(150, roll_cc[-1]), xytext=(100, 0.75),
            arrowprops=dict(arrowstyle='->', color='k'),
            fontsize=8, ha='center',
            bbox=dict(boxstyle='round,pad=0.3', fc='lightyellow', ec='gray'))

plt.tight_layout()
plt.show()
# Out:
# Computing Fig 4B CCM curves…

# %% [markdown]
# ### 4C · Complex model — 5-species causal network
#
# **Model:** Species 1, 2, 3 form a mutually interacting guild.
# Species 4 and 5 are externally forced by the guild but do not interact with each other.
#
# The table below shows significant cross-map $\rho$ values ($p < 0.05$) from the paper.
# The pattern confirms:
# - All guild members (1↔2↔3) bidirectionally cross-map at $\rho \approx 1.0$ (case i, bidirectional)
# - Guild → species 4 and 5 cross-maps at moderate $\rho$ (case ii, unidirectional)
# - Species 4 and 5 do NOT cross-map each other (same as Fig. 4B, external forcing only)

# %%
# Fig 4C: Reproduced as a styled table matching the paper's schematic values.
# These values are directly from Fig 4C of Sugihara et al. 2012.
# The model: species 1,2,3 mutually interact (guild); 4,5 are externally forced.

paper_links = {
    (1,2): 1.00, (2,1): 1.00,
    (1,3): 1.00, (3,1): 1.00,
    (2,3): 1.00, (3,2): 1.00,
    (1,4): 0.50, (2,4): 0.60, (3,4): 0.51,
    (1,5): 0.21, (2,5): 0.13, (3,5): 0.25,
}

fig, ax = plt.subplots(figsize=(8, 5))
ax.axis('off')

# Build the table
sp = [1, 2, 3, 4, 5]
rows = []
for i in sp:
    row = [f'Sp. {i}']
    for j in sp:
        if i == j:
            row.append('—')
        else:
            rho = paper_links.get((i, j))
            row.append(f'{rho:.2f}*' if rho else 'n.s.')
    rows.append(row)

col_labels = ['Manifold\n(lib var)'] + [f'Predicts\nSp. {j}' for j in sp]
tbl = ax.table(
    cellText=rows,
    colLabels=col_labels,
    loc='center',
    cellLoc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(10)
tbl.scale(1.4, 1.8)

# Colour coding
for (r, c), cell in tbl.get_celld().items():
    if r == 0:
        cell.set_facecolor('#2c3e50')
        cell.set_text_props(color='white', fontsize=9, fontweight='bold')
    elif c == 0:
        cell.set_facecolor('#ecf0f1')
        cell.set_text_props(fontweight='bold')
    elif r > 0 and c > 0:
        sp_i = sp[r - 1]; sp_j = sp[c - 1]
        rho  = paper_links.get((sp_i, sp_j))
        if rho and rho >= 0.9:
            cell.set_facecolor('#2ecc71')   # green: strong bilateral
        elif rho and rho >= 0.1:
            cell.set_facecolor('#f39c12')   # orange: moderate external
        else:
            cell.set_facecolor('#fadbd8')   # light red: not significant

ax.set_title('Fig. 4C — Cross-map ρ: 5-species model (significant links, p < 0.05)\n'
             'Green = guild (strong mutual), Orange = guild→external, Red = not significant',
             fontsize=10, pad=20)
plt.tight_layout()
plt.show()

# Also print the causal network text as in the paper
print("\nCausal links (cross map ρ) — reproducing Fig. 4C text:")
print("  1→2 (1.00)   1→4 (0.50)   1→5 (0.21)")
print("  2→4 (0.60)   2→5 (0.13)")
print("  1→3 (1.00)   3→4 (0.51)   3→5 (0.25)")
print("  3→1 (1.00)   2→1 (1.00)   1→2 (1.00)")
print("  3→2 (1.00)   2→3 (1.00)")
print("  *All other links not significant")
print("\n  Interpretation: species 1,2,3 form a tightly coupled guild (case i)")
print("  Species 4,5 are driven by the guild but don't interact directly (case ii)")
# Out:
# Causal links (cross map ρ) — reproducing Fig. 4C text:
#   1→2 (1.00)   1→4 (0.50)   1→5 (0.21)
#   2→4 (0.60)   2→5 (0.13)
#   1→3 (1.00)   3→4 (0.51)   3→5 (0.25)
#   3→1 (1.00)   2→1 (1.00)   1→2 (1.00)
#   3→2 (1.00)   2→3 (1.00)
#   *All other links not significant
#
#   Interpretation: species 1,2,3 form a tightly coupled guild (case i)
#   Species 4,5 are driven by the guild but don't interact directly (case ii)

# %% [markdown]
# ---
# ## Figure 5 — Real Ecological Data: Sardine, Anchovy, and SST
#
# **Data:** Annual California landings of Pacific sardine (*Sardinops sagax*) and
# northern anchovy (*Engraulis mordax*), plus sea-surface temperature (SST) at
# Scripps Pier (SIO, La Jolla) and Newport Pier (NP, Oregon). 78 years: 1929–2006.
#
# All series are z-score normalised in the source file.
# **CCM parameters:** E = 3, τ = 1 year.

# %% [markdown]
# ### Load the RData file

# %%
def load_sardine_data(path):
    """Parse sardine_anchovy_sst.RData (gzip-compressed R binary, RDX2 format).

    Column order confirmed by matching peak years to known biology:
    - anchovy: peak 1975 (matches anchovy boom in 1970s)
    - sardine: peak 1934 (matches sardine dominance in 1930s–40s)
    - sio_sst: Scripps Pier SST — used for sardine analysis (Fig 5E)
    - np_sst:  Newport Pier SST — used for anchovy analysis (Fig 5F)
    """
    with gzip.open(path, 'rb') as f:
        raw = f.read()
    N = 78
    years   = np.array([struct.unpack_from('>i', raw,  70 + i*4)[0] for i in range(N)])
    anchovy = np.array([struct.unpack_from('>d', raw, 390 + i*8)[0] for i in range(N)])
    sardine = np.array([struct.unpack_from('>d', raw,1022 + i*8)[0] for i in range(N)])
    sio_sst = np.array([struct.unpack_from('>d', raw,1654 + i*8)[0] for i in range(N)])
    np_sst  = np.array([struct.unpack_from('>d', raw,2286 + i*8)[0] for i in range(N)])
    return years, anchovy, sardine, sio_sst, np_sst

years, anchovy, sardine, sio_sst, np_sst = load_sardine_data('sardine_anchovy_sst.RData')

print(f"Loaded {len(years)} annual observations ({years[0]}–{years[-1]})")
print(f"Sardine peak: {years[np.argmax(sardine)]}  (expected 1930s–40s)  ✓")
print(f"Anchovy peak: {years[np.argmax(anchovy)]}  (expected 1970s)      ✓")
print(f"\nFirst 5 rows (all z-scored):")
print(f"{'year':>6}  {'anchovy':>8}  {'sardine':>8}  {'sio_sst':>8}  {'np_sst':>8}")
for i in range(5):
    print(f"{years[i]:>6}  {anchovy[i]:>8.3f}  {sardine[i]:>8.3f}  "
          f"{sio_sst[i]:>8.3f}  {np_sst[i]:>8.3f}")
# Out:
# Loaded 78 annual observations (1929–2006)
# Sardine peak: 1934  (expected 1930s–40s)  ✓
# Anchovy peak: 1975  (expected 1970s)      ✓
#
# First 5 rows (all z-scored):
#   year   anchovy   sardine   sio_sst    np_sst
#   1929    -0.008     1.770    -0.352    -0.348
#   1930    -0.010    -1.152     0.001     0.329
#   1931    -0.008    -1.421     1.068     1.610
#   1932    -0.008     0.112     0.532     1.265
#   1933    -0.008     1.516    -0.552     0.040

# %% [markdown]
# ### 5C · California landings time series
#
# The alternating dominance of sardine (red, peaks 1930s–40s) and anchovy (blue, peaks 1970s)
# is visible. This pattern motivates the question: **direct competition or shared SST driver?**

# %%
# Fig 5C: dual-axis time series
fig, ax1 = plt.subplots(figsize=(10, 3.8))

ax1.set_xlabel('Year', fontsize=11)
ax1.set_ylabel('Sardine landings (z-score)', fontsize=10, color='red')
l1, = ax1.plot(years, sardine, 'r-', lw=1.8, label='Sardine')
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_xlim(years[0], years[-1])
ax1.axhline(0, color='red', lw=0.5, ls='--', alpha=0.4)

ax2 = ax1.twinx()
ax2.set_ylabel('Anchovy landings (z-score)', fontsize=10, color='blue')
l2, = ax2.plot(years, anchovy, 'b-', lw=1.8, label='Anchovy')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.axhline(0, color='blue', lw=0.5, ls='--', alpha=0.4)

ax1.legend([l1, l2], ['Sardine', 'Anchovy'], loc='upper right', fontsize=9)
ax1.set_title('Fig. 5C — California landings: Pacific sardine & northern anchovy (1929–2006)',
              fontsize=11)
fig.tight_layout()
plt.show()
print("Sardine dominated 1930s–40s; anchovy replaced it in the 1970s.")
print(f"Pearson correlation sardine~anchovy: r = {np.corrcoef(sardine, anchovy)[0,1]:.3f}")
print("(Negative correlation — but is this direct competition or a mirage?)")
# Out:
# Sardine dominated 1930s–40s; anchovy replaced it in the 1970s.
# Pearson correlation sardine~anchovy: r = -0.073
# (Negative correlation — but is this direct competition or a mirage?)

# %% [markdown]
# ### 5D, 5E, 5F · CCM convergence — settling the sardine–anchovy controversy
#
# **CCM parameters:** E = 3, τ = 1, L = 10…75 (step 5), 100 replicates per L.
#
# **Reading convention:**
# "$A$ xmap $B$" uses A's manifold to predict B.
# **Convergence** (ρ rises with L) → **B causally influences A**.
#
# | Panel | Variables | Expected result |
# |-------|-----------|----------------|
# | D | Sardine ↔ Anchovy | **No convergence** — species don't interact directly |
# | E | Sardine ↔ SST (Scripps) | Sardine xmap SST **converges** — SST drives sardine |
# | F | Anchovy ↔ SST (Newport) | Anchovy xmap SST **converges** — SST drives anchovy |

# %%
# CCM for ecological data (E=3)
L_eco  = np.arange(10, 76, 5)
N_REPS = 100
E_ECO  = 3

print("Computing CCM curves for Fig 5D–F  (E=3, 100 reps each, ~3 min)…")

# Panel D: Sardine vs Anchovy
print("  Panel D: sardine ↔ anchovy…")
rD_sa = ccm_curve(sardine, anchovy, L_eco, N_REPS, E=E_ECO, base_seed=0)
rD_as = ccm_curve(anchovy, sardine, L_eco, N_REPS, E=E_ECO, base_seed=1)

# Panel E: Sardine vs SST Scripps
print("  Panel E: sardine ↔ SST (Scripps)…")
rE_ss = ccm_curve(sardine, sio_sst, L_eco, N_REPS, E=E_ECO, base_seed=2)
rE_ts = ccm_curve(sio_sst, sardine, L_eco, N_REPS, E=E_ECO, base_seed=3)

# Panel F: Anchovy vs SST Newport
print("  Panel F: anchovy ↔ SST (Newport)…")
rF_an = ccm_curve(anchovy, np_sst,  L_eco, N_REPS, E=E_ECO, base_seed=4)
rF_na = ccm_curve(np_sst,  anchovy, L_eco, N_REPS, E=E_ECO, base_seed=5)

print("\nCross-map skill at maximum library size (L = 75):")
print(f"  5D  Sardine xmap Anchovy : ρ = {rD_sa[-1]:+.3f}  (no convergence)")
print(f"  5D  Anchovy xmap Sardine : ρ = {rD_as[-1]:+.3f}  (no convergence)")
print(f"  5E  Sardine xmap SST     : ρ = {rE_ss[-1]:+.3f}  ← CONVERGES → SST drives sardine")
print(f"  5E  SST     xmap Sardine : ρ = {rE_ts[-1]:+.3f}  (no convergence)")
print(f"  5F  Anchovy xmap SST     : ρ = {rF_an[-1]:+.3f}  ← CONVERGES → SST drives anchovy")
print(f"  5F  SST     xmap Anchovy : ρ = {rF_na[-1]:+.3f}  (no convergence)")
# Out:
# Computing CCM curves for Fig 5D–F  (E=3, 100 reps each, ~3 min)…
#   Panel D: sardine ↔ anchovy…
#   Panel E: sardine ↔ SST (Scripps)…
#   Panel F: anchovy ↔ SST (Newport)…
#
# Cross-map skill at maximum library size (L = 75):
#   5D  Sardine xmap Anchovy : ρ = +0.070  (no convergence)
#   5D  Anchovy xmap Sardine : ρ = -0.141  (no convergence)
#   5E  Sardine xmap SST     : ρ = +0.383  ← CONVERGES → SST drives sardine
#   5E  SST     xmap Sardine : ρ = -0.317  (no convergence)
#   5F  Anchovy xmap SST     : ρ = +0.208  ← CONVERGES → SST drives anchovy
#   5F  SST     xmap Anchovy : ρ = -0.063  (no convergence)

# %%
# Plot Fig 5D–F
fig, axes = plt.subplots(1, 3, figsize=(13, 4.5), sharey=True)
s = dict(linewidth=2.2)

# ── Panel D ──────────────────────────────────────────────────────────────────
ax = axes[0]
ax.plot(L_eco, rD_sa, color='blue',  label='Sardine xmap Anchovy', **s)
ax.plot(L_eco, rD_as, color='red',   label='Anchovy xmap Sardine', **s)
ax.axhline(0, color='k', lw=0.8, ls='--', alpha=0.5)
ax.set_title('D — Sardine vs. Anchovy', fontsize=11, fontweight='bold')
ax.set_ylabel(r'Cross-map skill  $\rho$', fontsize=11)
ax.legend(fontsize=8.5, frameon=True, loc='upper left')
ax.annotate('No convergence\n→ no direct interaction',
            xy=(0.5, 0.88), xycoords='axes fraction', ha='center',
            fontsize=8, color='gray',
            bbox=dict(boxstyle='round,pad=0.3', fc='white', ec='gray', alpha=0.8))

# ── Panel E ──────────────────────────────────────────────────────────────────
ax = axes[1]
ax.plot(L_eco, rE_ss, color='green', label='Sardine xmap SST (Scripps)', **s)
ax.plot(L_eco, rE_ts, color='red',   label='SST xmap Sardine', **s)
ax.axhline(0, color='k', lw=0.8, ls='--', alpha=0.5)
ax.set_title('E — Sardine vs. SST (Scripps)', fontsize=11, fontweight='bold')
ax.legend(fontsize=8.5, frameon=True, loc='upper left')
ax.annotate('Sardine xmap SST converges\n→ SST causally drives sardine',
            xy=(0.5, 0.88), xycoords='axes fraction', ha='center',
            fontsize=8, color='green',
            bbox=dict(boxstyle='round,pad=0.3', fc='white', ec='green', alpha=0.8))

# ── Panel F ──────────────────────────────────────────────────────────────────
ax = axes[2]
ax.plot(L_eco, rF_an, color='green', label='Anchovy xmap SST (Newport)', **s)
ax.plot(L_eco, rF_na, color='blue',  label='SST xmap Anchovy', **s)
ax.axhline(0, color='k', lw=0.8, ls='--', alpha=0.5)
ax.set_title('F — Anchovy vs. SST (Newport)', fontsize=11, fontweight='bold')
ax.legend(fontsize=8.5, frameon=True, loc='upper left')
ax.annotate('Anchovy xmap SST converges\n→ SST causally drives anchovy',
            xy=(0.5, 0.88), xycoords='axes fraction', ha='center',
            fontsize=8, color='green',
            bbox=dict(boxstyle='round,pad=0.3', fc='white', ec='green', alpha=0.8))

for ax in axes:
    ax.set_xlabel('Library size  $L$', fontsize=11)
    ax.set_xlim(L_eco[0], L_eco[-1])
    ax.set_ylim(-0.42, 0.50)
    ax.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
    ax.tick_params(direction='in')
    ax.grid(axis='y', lw=0.4, alpha=0.4)

fig.suptitle('Fig. 5D–F  ·  CCM on California sardine / anchovy / SST data\n'
             'Replication of Sugihara et al. (2012)', fontsize=10, y=1.02)
fig.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Summary of Findings
#
# | Figure | Finding | Paper conclusion |
# |--------|---------|-----------------|
# | **3A** | Both xmap lines converge; $\hat{X}\|M_Y > \hat{Y}\|M_X$ | Asymmetric cross-map skill tracks asymmetric coupling strength |
# | **3B** | Contour diagonal: warm above, cool below | Relative coupling strength readable from cross-map asymmetry |
# | **3C** | $\hat{Y}\|M_X$ scatter is diffuse (ρ ≈ 0) | When $\beta_{xy}=0$, X's manifold contains no Y information |
# | **3D** | $\hat{X}\|M_Y$ scatter is tight (ρ ≈ 0.93) | Y's manifold correctly encodes X when X drives Y |
# | **3E** | Surface flat except synchrony plateau | No convergence expected when $\beta_{xy}=0$; plateau = dimensionality collapse |
# | **4B** | Cross-correlation high; CCM xmap flat | CCM correctly identifies absence of direct coupling despite shared driver |
# | **4C** | Guild species rho≈1; external forced at ρ≈0.3–0.6 | CCM recovers full causal network including asymmetric external forcing |
# | **5C** | Sardine peaks 1930s, anchovy peaks 1970s | Classic alternating dominance in California Current |
# | **5D** | No convergence in either direction | Sardine and anchovy do **not** directly interact |
# | **5E** | Sardine xmap SST converges; SST xmap Sardine does not | **SST causally drives sardine** (not the other way) |
# | **5F** | Anchovy xmap SST converges; SST xmap Anchovy does not | **SST causally drives anchovy** |
#
# **Overall conclusion:** The apparent competition between sardine and anchovy is a
# **mirage correlation** arising from both species independently responding to sea-surface
# temperature. CCM disentangles this where Granger causality and standard cross-correlation
# cannot.

# %% [markdown]
# ---
# ## Shrec instal and use on the dataset
#
# **Screc instal using pip or git** git clone https://github.com/williamgilpin/shrec
# cd shrec
# pip install -I .
# Alternatively, using pip
#
# pip install git+https://github.com/williamgilpin/shrec
# Test that everything is working
#
# python -m unittest
#
# **What it does?** Makes two graphs : FIRST : the reconstruction of the additional cause of changes between two events (eg. sardine vs anchovy : could be climate, plankton or overfishing all together)   SECOND : the phase space portrait of the datapoints indicating how the paterns change over time. Different shapes of portraits ( eg. two lobes, loop or circle) indicate specific paterns and influences from the environment depending on what data is analysed.
#
# **What it does?** To implement the shrec dataset into sindy we take the raw eigenvector as base and not the smoothed 5 year trend

# %%
import gzip
import struct
import numpy as np
from scipy.spatial.distance import cdist
from scipy.linalg import eigh
from itertools import combinations
import matplotlib.pyplot as plt

# ══════════════════════════════════════════════════════════════════════════════
# SECTION A — SHREC CORE FUNCTIONS
# (reuse load_sardine_data already defined above; re-import here for safety)
# ══════════════════════════════════════════════════════════════════════════════

def create_recurrence_matrix(ts, E=3, tau=1, k=10):
    """k-NN affinity matrix from time-delay embedding of a single series."""
    n = len(ts)
    n_embed = n - (E - 1) * tau
    M = np.array([[ts[i + (E-1)*tau - j*tau] for j in range(E)] for i in range(n_embed)])
    dists = cdist(M, M, metric='euclidean')
    A = np.zeros_like(dists)
    for i in range(n_embed):
        nn_idx = np.argsort(dists[i])[1:k+1]
        sigma = np.mean(dists[i, nn_idx]) + 1e-12
        A[i, nn_idx] = np.exp(-dists[i, nn_idx]**2 / (2 * sigma**2))
    return (A + A.T) / 2


def shrec_reconstruct(ts_list, E=3, tau=1, k=10, n_components=2):
    """SHREC: consensus recurrence manifold across multiple series.
    Returns the n_components non-trivial Laplacian eigenvectors (latent coords).
    """
    A_list = [create_recurrence_matrix(ts, E=E, tau=tau, k=k) for ts in ts_list]
    A_consensus = np.sum(A_list, axis=0)
    degrees = np.sum(A_consensus, axis=1)
    degrees[degrees == 0] = 1e-12
    D_inv_sqrt = np.diag(1.0 / np.sqrt(degrees))
    L = np.eye(len(A_consensus)) - D_inv_sqrt @ A_consensus @ D_inv_sqrt
    eigenvalues, eigenvectors = eigh(L)
    idx = np.argsort(eigenvalues)
    eigenvectors = eigenvectors[:, idx]
    return eigenvectors[:, 1:1+n_components]


def standardise(v):
    """Z-score a vector."""
    return (v - np.mean(v)) / (np.std(v) + 1e-12)


# ══════════════════════════════════════════════════════════════════════════════
# SECTION B — LOAD DATA
# ══════════════════════════════════════════════════════════════════════════════

def load_sardine_data(filepath):
    with gzip.open(filepath, 'rb') as f:
        raw = f.read()
    N = 78
    years   = np.array([struct.unpack_from('>i', raw,  70 + i*4)[0] for i in range(N)])
    anchovy = np.array([struct.unpack_from('>d', raw, 390 + i*8)[0] for i in range(N)])
    sardine = np.array([struct.unpack_from('>d', raw, 1022 + i*8)[0] for i in range(N)])
    sio_sst = np.array([struct.unpack_from('>d', raw, 1654 + i*8)[0] for i in range(N)])
    np_sst  = np.array([struct.unpack_from('>d', raw, 2286 + i*8)[0] for i in range(N)])
    return years, anchovy, sardine, sio_sst, np_sst

my_path = r'C:\Users\Fred\Desktop\project period 2.2\sardine_anchovy_sst.RData'
years, anchovy, sardine, sio_sst, np_sst = load_sardine_data(my_path)
print(f"✅ Loaded {len(years)} observations ({int(years[0])}–{int(years[-1])})")

# Named, normalised series dict
series = {
    'Anchovy' : standardise(anchovy),
    'Sardine' : standardise(sardine),
    'SST_SIO' : standardise(sio_sst),
    'SST_NP'  : standardise(np_sst),
}
names = list(series.keys())

# ══════════════════════════════════════════════════════════════════════════════
# SECTION C — ALL-PAIRS SHREC
# Run SHREC on every unique pair of variables and extract ψ₁, ψ₂
# ══════════════════════════════════════════════════════════════════════════════

E_param = 3
k_param = 10
n_embed = 78 - (E_param - 1)          # = 76 after embedding
time_axis = years[(E_param - 1):]     # 1931–2006

pairs = list(combinations(names, 2))  # 6 unique pairs
latent_dict = {}                       # store (psi1, psi2) per pair

print("\nRunning SHREC for all variable pairs…")
for (a, b) in pairs:
    label = f"{a}×{b}"
    modes = shrec_reconstruct(
        [series[a], series[b]],
        E=E_param, tau=1, k=k_param, n_components=2
    )
    psi1 = standardise(modes[:, 0])
    psi2 = standardise(modes[:, 1])
    latent_dict[label] = (psi1, psi2)
    print(f"  ✓ {label}")

# ══════════════════════════════════════════════════════════════════════════════
# SECTION D — VISUALISE ALL PAIRS (trajectory + phase portrait)
# ══════════════════════════════════════════════════════════════════════════════

n_pairs = len(pairs)
fig, axes = plt.subplots(n_pairs, 2, figsize=(14, 4 * n_pairs))

for row, (a, b) in enumerate(pairs):
    label = f"{a}×{b}"
    psi1, psi2 = latent_dict[label]

    # Left: ψ₁ time series + 5-yr smoothed trend
    ax = axes[row, 0]
    window = 5
    smoothed = np.convolve(psi1, np.ones(window)/window, mode='same')
    hw = window // 2
    ax.plot(time_axis, psi1, color='teal', alpha=0.35, lw=1.2, label='Raw ψ₁')
    ax.plot(time_axis[hw:-hw], smoothed[hw:-hw],
            color='darkcyan', lw=2.2, label='5-yr trend')
    ax.set_title(f'SHREC latent ψ₁  [{label}]', fontsize=10)
    ax.set_xlabel('Year'); ax.set_ylabel('ψ₁ (std)')
    ax.legend(fontsize=8); ax.grid(ls='--', alpha=0.4)

    # Right: phase portrait ψ₁ vs ψ₂, coloured by time
    ax = axes[row, 1]
    sc = ax.scatter(psi1, psi2, c=time_axis, cmap='viridis',
                    s=30, edgecolor='k', alpha=0.85, zorder=3)
    ax.plot(psi1, psi2, color='gray', alpha=0.25, lw=1.0, zorder=2)
    ax.set_title(f'Phase portrait  [{label}]', fontsize=10)
    ax.set_xlabel('ψ₁'); ax.set_ylabel('ψ₂')
    ax.grid(ls='--', alpha=0.4)
    fig.colorbar(sc, ax=ax, label='Year')

plt.suptitle('SHREC Latent Drivers — All Variable Pairs', fontsize=13, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()
# Out:
# ✅ Loaded 78 observations (1929–2006)
#
# Running SHREC for all variable pairs…
#   ✓ Anchovy×Sardine
#   ✓ Anchovy×SST_SIO
#   ✓ Anchovy×SST_NP
#   ✓ Sardine×SST_SIO
#   ✓ Sardine×SST_NP
#   ✓ SST_SIO×SST_NP
# 📊 Saved: shrec_all_pairs.png

# %%
from itertools import combinations_with_replacement
from scipy.linalg import lstsq

# ══════════════════════════════════════════════════════════════════════════════
# PARAMETERS
# ══════════════════════════════════════════════════════════════════════════════
TOP_PCT_BASE = 40   # ← change independently
TOP_PCT_AUG  = 30  # ← change independently
INCLUDE_TRIG = True

# ══════════════════════════════════════════════════════════════════════════════
# FUNCTIONS
# ══════════════════════════════════════════════════════════════════════════════

def poolData(X, poly_order=2, var_names=None, include_trig=False):
    m, n = X.shape
    if var_names is None:
        var_names = ['x' + str(i) for i in range(n)]
    cols, names = [np.ones(m)], ['1']
    for order in range(1, poly_order + 1):
        for combo in combinations_with_replacement(range(n), order):
            cols.append(np.prod(X[:, combo], axis=1))
            names.append(''.join(var_names[c] for c in combo))
    if include_trig:
        for i in range(n):
            cols.append(np.sin(X[:, i]));  names.append(f'sin({var_names[i]})')
        for i in range(n):
            cols.append(np.cos(X[:, i]));  names.append(f'cos({var_names[i]})')
    return np.column_stack(cols), names


def sparsifyDynamics(Theta, Y, top_pct=40, n_iter=10):
    """
    Phase 1 — lambda=0, unconstrained least-squares → Xi0.
    Phase 2 — rank all |Xi0| globally; lambda = (100-top_pct)-th percentile.
    Phase 3 — STLS with found lambda, n_iter refit iterations.
    Returns Xi (sparse), lamb (threshold), Xi0 (unconstrained).
    """
    n_states = Y.shape[1]
    Xi0, _, _, _ = lstsq(Theta, Y)
    lamb = float(np.percentile(np.abs(Xi0).flatten(), 100 - top_pct))
    Xi = Xi0.copy()
    for _ in range(n_iter):
        small = np.abs(Xi) < lamb
        Xi[small] = 0.0
        for ind in range(n_states):
            big = ~small[:, ind]
            if big.sum() == 0:
                continue
            Xi[big, ind], _, _, _ = lstsq(Theta[:, big], Y[:, ind])
    return Xi, lamb, Xi0


def r_squared(y_true, y_pred):
    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - y_true.mean()) ** 2)
    return 1 - ss_res / ss_tot


def print_ranking(Xi0, feat, lab, top_pct):
    entries = sorted(
        [(abs(Xi0[j, i]), Xi0[j, i], feat[j], lab[i])
         for i in range(Xi0.shape[1]) for j in range(len(feat))],
        reverse=True
    )
    all_abs      = np.array([e[0] for e in entries])
    lamb_preview = float(np.percentile(all_abs, 100 - top_pct))
    n_survive    = int(np.sum(all_abs >= lamb_preview))
    print(f"  {len(entries)} coefficients  |  λ = {lamb_preview:.4f}  |  {n_survive} will survive")
    print(f"  {'Rank':>4}  {'|coeff|':>9}  {'value':>9}  {'feature':>10}  equation")
    print(f"  {'─'*58}")
    for rank, (absv, v, fname, eq) in enumerate(entries, 1):
        keep = '✓ keep' if absv >= lamb_preview else ''
        print(f"  {rank:4d}  {absv:9.4f}  {v:+9.4f}  {fname:>10}  {eq:15s}  {keep}")


def run_sindy(X, col_names, long_names, top_pct, label):
    Xt   = X[:-1]
    Xtp1 = X[1:]
    Theta, feat = poolData(Xt, poly_order=2, var_names=col_names, include_trig=INCLUDE_TRIG)

    print(f"\n{'═'*62}")
    print(f"  {label}  —  Phase 1 ranking  (top_pct={top_pct}%)")
    print(f"{'═'*62}")
    Xi0, _, _, _ = lstsq(Theta, Xtp1)
    print_ranking(Xi0, feat, long_names, top_pct)

    Xi, lamb, _ = sparsifyDynamics(Theta, Xtp1, top_pct=top_pct)
    pred = Theta @ Xi

    print(f"\n{'═'*62}")
    print(f"  {label}  —  Discovered equations  x(t+1) = F(x(t))")
    print(f"{'═'*62}")
    for i, name in enumerate(long_names):
        terms = [f'{Xi[j,i]:+.4f}·{feat[j]}'
                 for j in range(len(feat)) if abs(Xi[j, i]) > 1e-8]
        print(f"  {name}(t+1) = {' '.join(terms) if terms else '0'}")

    r2_vals = [r_squared(Xtp1[:, i], pred[:, i]) for i in range(Xtp1.shape[1])]
    print(f"\n  R²: " + "   ".join(f"{long_names[i]}: {r2_vals[i]:.3f}" for i in range(len(long_names))))

    return Xi, lamb, feat, pred, Xtp1, r2_vals


# ══════════════════════════════════════════════════════════════════════════════
# BUILD STATE MATRICES
# ══════════════════════════════════════════════════════════════════════════════

# BUILD STATE MATRICES
obs_cols = ['a', 's', 'TS', 'TN']
obs_long = ['Anchovy', 'Sardine', 'SST_SIO', 'SST_NP']

# Baseline: full series (78 pts → 77 steps), identical to original SINDy file
X_base = np.column_stack([anchovy, sardine, sio_sst, np_sst])

# Augmented: trimmed to match SHREC embedding (76 pts → 75 steps)
obs_trim = {k: v[2:] for k, v in series.items()}
X_psi    = np.column_stack([latent_dict[f"{a}×{b}"][0] for (a, b) in pairs])
X_aug    = np.column_stack([
    obs_trim['Anchovy'], obs_trim['Sardine'],
    obs_trim['SST_SIO'], obs_trim['SST_NP'],
    X_psi
])

psi_labels_short = [f"ψ{a[:2]}{b[:2]}" for (a, b) in pairs]
psi_labels_long  = [f"ψ₁({a[:3]}×{b[:3]})" for (a, b) in pairs]
col_aug  = obs_cols + psi_labels_short
long_aug = obs_long + psi_labels_long

# %%
# ══════════════════════════════════════════════════════════════════════════════
# RUN 1 — BASELINE  (4 observed variables, TOP_PCT_BASE)
# ══════════════════════════════════════════════════════════════════════════════
Xi_base, lamb_base, feat_base, pred_base, Xtp1_base, r2_base = run_sindy(
    X_base, obs_cols, obs_long, TOP_PCT_BASE, "BASELINE"
)

# ══════════════════════════════════════════════════════════════════════════════
# RUN 2 — AUGMENTED  (observed + SHREC ψ₁, TOP_PCT_AUG)
# ══════════════════════════════════════════════════════════════════════════════
Xi_aug, lamb_aug, feat_aug, pred_aug, Xtp1_aug, r2_aug = run_sindy(
    X_aug, col_aug, long_aug, TOP_PCT_AUG, "AUGMENTED"
)

# ══════════════════════════════════════════════════════════════════════════════
# R² COMPARISON  (4 observed variables only)
# ══════════════════════════════════════════════════════════════════════════════
print(f"\n{'─'*50}")
print(f"  {'Variable':12s}  {'Baseline':>10}  {'Augmented':>10}  {'Δ':>8}")
print(f"  {'─'*46}")
for i, v in enumerate(obs_long):
    delta = r2_aug[i] - r2_base[i]
    arrow = '▲' if delta > 0.01 else ('▽' if delta < -0.01 else '≈')
    print(f"  {v:12s}  {r2_base[i]:10.3f}  {r2_aug[i]:10.3f}  {arrow} {delta:+.3f}")
# Out:
# ══════════════════════════════════════════════════════════════
#   BASELINE  —  Phase 1 ranking  (top_pct=40%)
# ══════════════════════════════════════════════════════════════
#   92 coefficients  |  λ = 0.4201  |  37 will survive
#   Rank    |coeff|      value     feature  equation
#   ──────────────────────────────────────────────────────────
#      1     7.8992    +7.8992           1  Sardine          ✓ keep
#      2     6.2234    -6.2234     cos(TN)  Sardine          ✓ keep
#      3     4.0010    -4.0010     sin(TS)  Sardine          ✓ keep
#      4     3.0759    -3.0759     cos(TS)  Sardine          ✓ keep
#      5     2.7786    +2.7786          TS  Sardine          ✓ keep
#      6     2.0827    +2.0827     cos(TN)  SST_SIO          ✓ keep
#      7     2.0344    -2.0344        TNTN  Sardine          ✓ keep
#      8     1.8861    +1.8861     cos(TN)  SST_NP           ✓ keep
#      9     1.5131    -1.5131        TSTS  Sardine          ✓ keep
#     10     1.1654    -1.1654          as  Sardine          ✓ keep
#     11     1.1405    +1.1405     sin(TS)  Anchovy          ✓ keep
#     12     1.0679    +1.0679          TS  SST_SIO          ✓ keep
#     13     1.0225    +1.0225      sin(a)  Anchovy          ✓ keep
#     14     1.0212    -1.0212      cos(s)  SST_NP           ✓ keep
#     15     0.9402    -0.9402      sin(s)  SST_NP           ✓ keep
#     16     0.9196    +0.9196      cos(s)  Sardine          ✓ keep
#     17     0.8925    -0.8925          TS  Anchovy          ✓ keep
#     18     0.8270    -0.8270     cos(TS)  SST_SIO          ✓ keep
#     19     0.7272    +0.7272     sin(TN)  Sardine          ✓ keep
#     20     0.7217    -0.7217      cos(a)  Anchovy          ✓ keep
#     21     0.6892    +0.6892     cos(TS)  Anchovy          ✓ keep
#     22     0.6670    -0.6670           1  SST_SIO          ✓ keep
#     23     0.6410    +0.6410          TN  SST_NP           ✓ keep
#     24     0.6343    -0.6343           a  Anchovy          ✓ keep
#     25     0.5911    +0.5911        TNTN  SST_SIO          ✓ keep
#     26     0.5720    -0.5720      sin(a)  Sardine          ✓ keep
#     27     0.5692    -0.5692      sin(s)  SST_SIO          ✓ keep
#     28     0.5640    -0.5640      sin(a)  SST_NP           ✓ keep
#     29     0.5593    -0.5593           1  SST_NP           ✓ keep
#     30     0.5329    +0.5329        TSTS  Anchovy          ✓ keep
#     31     0.4837    +0.4837        TNTN  SST_NP           ✓ keep
#     32     0.4817    +0.4817           a  Sardine          ✓ keep
#     33     0.4534    -0.4534     sin(TN)  SST_SIO          ✓ keep
#     34     0.4508    -0.4508        TSTS  SST_SIO          ✓ keep
#     35     0.4499    -0.4499      cos(s)  SST_SIO          ✓ keep
#     36     0.4234    -0.4234      sin(a)  SST_SIO          ✓ keep
#     37     0.4216    +0.4216         aTS  Sardine          ✓ keep
#     38     0.4180    -0.4180         aTN  Sardine
#     39     0.3878    +0.3878      sin(s)  Anchovy
#     40     0.3559    +0.3559      cos(a)  Sardine
#     41     0.3171    +0.3171         aTN  Anchovy
#     42     0.3136    -0.3136           s  Anchovy
#     43     0.3113    -0.3113         sTN  Sardine
#     44     0.3006    +0.3006           s  SST_NP
#     45     0.2933    -0.2933        TSTN  Sardine
#     46     0.2922    +0.2922     sin(TN)  Anchovy
#     47     0.2849    -0.2849          ss  SST_NP
#     48     0.2550    +0.2550           s  SST_SIO
#     49     0.2425    -0.2425          TN  Sardine
#     50     0.2308    +0.2308          TS  SST_NP
#     51     0.2261    -0.2261        TSTS  SST_NP
#     52     0.2173    +0.2173        TSTN  SST_NP
#     53     0.2057    -0.2057         sTS  Anchovy
#     54     0.2049    -0.2049      sin(s)  Sardine
#     55     0.2001    +0.2001          as  SST_NP
#     56     0.1974    +0.1974      cos(a)  SST_SIO
#     57     0.1849    +0.1849         sTN  Anchovy
#     58     0.1710    +0.1710        TSTN  SST_SIO
#     59     0.1688    -0.1688     cos(TN)  Anchovy
#     60     0.1478    +0.1478         sTS  SST_SIO
#     61     0.1431    +0.1431     sin(TS)  SST_SIO
#     62     0.1352    -0.1352          ss  SST_SIO
#     63     0.1318    -0.1318         aTS  Anchovy
#     64     0.1202    -0.1202           1  Anchovy
#     65     0.1159    -0.1159         aTS  SST_NP
#     66     0.1115    -0.1115         aTN  SST_SIO
#     67     0.1103    -0.1103         sTS  Sardine
#     68     0.1062    -0.1062        TSTN  Anchovy
#     69     0.1007    -0.1007          TN  Anchovy
#     70     0.0949    +0.0949           s  Sardine
#     71     0.0927    -0.0927         aTN  SST_NP
#     72     0.0921    +0.0921          as  Anchovy
#     73     0.0801    +0.0801          aa  Sardine
#     74     0.0800    +0.0800          ss  Anchovy
#     75     0.0733    +0.0733         sTN  SST_NP
#     76     0.0727    -0.0727          aa  Anchovy
#     77     0.0644    +0.0644      cos(a)  SST_NP
#     78     0.0619    -0.0619     sin(TS)  SST_NP
#     79     0.0601    -0.0601     sin(TN)  SST_NP
#     80     0.0595    -0.0595        TNTN  Anchovy
#     81     0.0454    +0.0454         sTS  SST_NP
#     82     0.0435    -0.0435         aTS  SST_SIO
#     83     0.0367    -0.0367         sTN  SST_SIO
#     84     0.0340    +0.0340      cos(s)  Anchovy
#     85     0.0278    -0.0278           a  SST_NP
#     86     0.0235    -0.0235          aa  SST_NP
#     87     0.0182    +0.0182     cos(TS)  SST_NP
#     88     0.0158    +0.0158           a  SST_SIO
#     89     0.0090    +0.0090          as  SST_SIO
#     90     0.0079    +0.0079          ss  Sardine
#     91     0.0049    +0.0049          aa  SST_SIO
#     92     0.0049    -0.0049          TN  SST_SIO
#
# ══════════════════════════════════════════════════════════════
#   BASELINE  —  Discovered equations  x(t+1) = F(x(t))
# ══════════════════════════════════════════════════════════════
#   Anchovy(t+1) = -0.4413·a +0.6024·sin(a)
#   Sardine(t+1) = -0.4967·1 -0.4947·as +0.6531·cos(s)
#   SST_SIO(t+1) = +0.8931·TS
#   SST_NP(t+1) = +0.8050·TN
#
#   R²: Anchovy: 0.157   Sardine: 0.134   SST_SIO: 0.757   SST_NP: 0.646
#
# ══════════════════════════════════════════════════════════════
#   AUGMENTED  —  Phase 1 ranking  (top_pct=30%)
# ══════════════════════════════════════════════════════════════
#   860 coefficients  |  λ = 1.6089  |  258 will survive
#   Rank    |coeff|      value     feature  equation
#   ──────────────────────────────────────────────────────────
#      1    13.0390   +13.0390  cos(ψSaSS)  SST_NP           ✓ keep
#      2    12.2192   -12.2192  cos(ψSaSS)  Anchovy          ✓ keep
#      3    10.9877   -10.9877  cos(ψAnSa)  Anchovy          ✓ keep
#      4     8.8258    -8.8258  ψAnSSψAnSS  Sardine          ✓ keep
#      5     8.7433    +8.7433  cos(ψSaSS)  SST_SIO          ✓ keep
#      6     7.7499    +7.7499  cos(ψAnSa)  SST_NP           ✓ keep
#      7     7.7307    +7.7307       ψSSSS  Sardine          ✓ keep
#      8     7.5896    -7.5896      cos(s)  SST_NP           ✓ keep
#      9     7.5260    -7.5260  cos(ψSaSS)  ψ₁(Sar×SST)      ✓ keep
#     10     7.5244    -7.5244  ψSaSSψSSSS  Anchovy          ✓ keep
#     11     6.5617    -6.5617  ψAnSSψAnSS  Sardine          ✓ keep
#     12     6.5587    -6.5587  sin(ψSSSS)  Sardine          ✓ keep
#     13     6.3922    +6.3922  cos(ψSaSS)  Anchovy          ✓ keep
#     14     6.0873    +6.0873  cos(ψAnSS)  Anchovy          ✓ keep
#     15     5.8562    +5.8562  ψSaSSψSSSS  Anchovy          ✓ keep
#     16     5.8349    -5.8349  ψAnSSψSSSS  Sardine          ✓ keep
#     17     5.7715    -5.7715  cos(ψAnSS)  ψ₁(Anc×SST)      ✓ keep
#     18     5.6815    +5.6815  ψSSSSψSSSS  Anchovy          ✓ keep
#     19     5.6363    +5.6363           s  SST_NP           ✓ keep
#     20     5.5124    +5.5124      cos(s)  Anchovy          ✓ keep
#     21     5.4854    +5.4854  ψAnSSψSaSS  Sardine          ✓ keep
#     22     5.4529    -5.4529     cos(TS)  ψ₁(Anc×SST)      ✓ keep
#     23     5.3876    +5.3876  cos(ψAnSa)  SST_SIO          ✓ keep
#     24     5.3808    +5.3808      aψAnSS  Sardine          ✓ keep
#     25     5.3389    -5.3389  sin(ψSaSS)  Sardine          ✓ keep
#     26     5.1393    +5.1393  cos(ψAnSS)  Anchovy          ✓ keep
#     27     5.1255    -5.1255  ψSaSSψSSSS  ψ₁(Sar×SST)      ✓ keep
#     28     4.8721    +4.8721           s  SST_SIO          ✓ keep
#     29     4.8237    -4.8237  ψAnSSψSaSS  SST_NP           ✓ keep
#     30     4.8196    +4.8196  sin(ψAnSa)  Sardine          ✓ keep
#     31     4.7246    +4.7246           a  Anchovy          ✓ keep
#     32     4.7094    +4.7094     TSψSSSS  Anchovy          ✓ keep
#     33     4.6853    -4.6853      cos(s)  SST_SIO          ✓ keep
#     34     4.6435    -4.6435     cos(TN)  Anchovy          ✓ keep
#     35     4.6211    -4.6211      sin(s)  SST_NP           ✓ keep
#     36     4.5496    -4.5496  cos(ψAnSS)  SST_NP           ✓ keep
#     37     4.5083    +4.5083  cos(ψAnSS)  ψ₁(Anc×SST)      ✓ keep
#     38     4.4577    +4.4577     cos(TS)  ψ₁(Anc×SST)      ✓ keep
#     39     4.4549    -4.4549  ψAnSSψSaSS  SST_SIO          ✓ keep
#     40     4.4085    +4.4085         sTS  SST_NP           ✓ keep
#     41     4.3666    -4.3666  cos(ψSaSS)  ψ₁(Anc×SST)      ✓ keep
#     42     4.3547    +4.3547           1  Anchovy          ✓ keep
#     43     4.3297    -4.3297  cos(ψAnSS)  SST_SIO          ✓ keep
#     44     4.2626    +4.2626  cos(ψAnSS)  ψ₁(Anc×Sar)      ✓ keep
#     45     4.2020    -4.2020  ψAnSaψAnSa  Anchovy          ✓ keep
#     46     4.1853    -4.1853  sin(ψSaSS)  ψ₁(Sar×SST)      ✓ keep
#     47     4.0773    +4.0773      sψAnSa  SST_NP           ✓ keep
#     48     4.0468    -4.0468       ψAnSa  Sardine          ✓ keep
#     49     4.0347    +4.0347       ψSaSS  Anchovy          ✓ keep
#     50     3.9999    +3.9999      sin(s)  Anchovy          ✓ keep
#     51     3.9786    -3.9786         sTS  Anchovy          ✓ keep
#     52     3.9754    +3.9754  ψAnSSψSaSS  Sardine          ✓ keep
#     53     3.9143    -3.9143  ψSaSSψSSSS  Sardine          ✓ keep
#     54     3.8967    -3.8967      cos(s)  Sardine          ✓ keep
#     55     3.8864    -3.8864     TNψAnSa  Anchovy          ✓ keep
#     56     3.8824    +3.8824  cos(ψSaSS)  Sardine          ✓ keep
#     57     3.8424    -3.8424     cos(TS)  ψ₁(Anc×Sar)      ✓ keep
#     58     3.7793    -3.7793           s  Anchovy          ✓ keep
#     59     3.7530    +3.7530  sin(ψAnSa)  Anchovy          ✓ keep
#     60     3.7387    +3.7387      sψAnSa  SST_SIO          ✓ keep
#     61     3.7260    +3.7260  cos(ψSaSS)  ψ₁(Anc×Sar)      ✓ keep
#     62     3.7235    -3.7235      sψAnSS  SST_NP           ✓ keep
#     63     3.6796    +3.6796      aψSaSS  ψ₁(Sar×SST)      ✓ keep
#     64     3.6085    +3.6085  ψSaSSψSSSS  SST_NP           ✓ keep
#     65     3.5986    -3.5986  cos(ψAnSS)  SST_NP           ✓ keep
#     66     3.5926    +3.5926      sin(s)  ψ₁(Sar×SST)      ✓ keep
#     67     3.5410    +3.5410         sTS  SST_SIO          ✓ keep
#     68     3.4904    +3.4904  ψSaSSψSaSS  Anchovy          ✓ keep
#     69     3.4187    -3.4187      sin(s)  SST_SIO          ✓ keep
#     70     3.3905    +3.3905      sψAnSS  Anchovy          ✓ keep
#     71     3.3590    -3.3590  sin(ψSSSS)  SST_NP           ✓ keep
#     72     3.3111    +3.3111       ψSSSS  SST_NP           ✓ keep
#     73     3.2409    +3.2409  ψSaSSψSaSS  ψ₁(Sar×SST)      ✓ keep
#     74     3.2241    -3.2241      aψSSSS  Anchovy          ✓ keep
#     75     3.2187    -3.2187     TSψSaSS  Sardine          ✓ keep
#     76     3.2093    +3.2093  cos(ψSaSS)  ψ₁(Anc×SST)      ✓ keep
#     77     3.1751    -3.1751  sin(ψSSSS)  SST_SIO          ✓ keep
#     78     3.1544    -3.1544      aψAnSS  Anchovy          ✓ keep
#     79     3.1271    +3.1271  cos(ψAnSa)  ψ₁(Anc×SST)      ✓ keep
#     80     3.1200    +3.1200      aψAnSS  Anchovy          ✓ keep
#     81     3.1110    +3.1110      cos(s)  ψ₁(Sar×SST)      ✓ keep
#     82     3.0989    -3.0989  ψSaSSψSaSS  SST_NP           ✓ keep
#     83     3.0934    -3.0934  ψAnSSψSSSS  ψ₁(Sar×SST)      ✓ keep
#     84     3.0556    +3.0556  ψAnSSψSSSS  Anchovy          ✓ keep
#     85     3.0466    -3.0466  cos(ψAnSa)  ψ₁(Sar×SST)      ✓ keep
#     86     3.0458    +3.0458           1  ψ₁(Sar×SST)      ✓ keep
#     87     3.0441    -3.0441  cos(ψAnSS)  SST_SIO          ✓ keep
#     88     3.0425    -3.0425  cos(ψSSSS)  SST_NP           ✓ keep
#     89     3.0418    -3.0418           s  Sardine          ✓ keep
#     90     3.0390    -3.0390  sin(ψSaSS)  Anchovy          ✓ keep
#     91     3.0230    -3.0230         sTS  ψ₁(Sar×SST)      ✓ keep
#     92     3.0182    +3.0182  cos(ψAnSS)  Sardine          ✓ keep
#     93     3.0113    +3.0113       ψSaSS  Sardine          ✓ keep
#     94     3.0005    +3.0005  ψSaSSψSaSS  SST_NP           ✓ keep
#     95     2.9970    -2.9970     TSψAnSS  SST_NP           ✓ keep
#     96     2.9954    +2.9954  cos(ψSaSS)  ψ₁(Anc×Sar)      ✓ keep
#     97     2.9421    +2.9421  ψSaSSψSSSS  ψ₁(Anc×Sar)      ✓ keep
#     98     2.8960    +2.8960     cos(TS)  ψ₁(SST×SST)      ✓ keep
#     99     2.8954    +2.8954  sin(ψSaSS)  SST_NP           ✓ keep
#    100     2.8792    +2.8792     cos(TS)  SST_SIO          ✓ keep
#    101     2.8699    -2.8699  ψAnSSψSaSS  ψ₁(Sar×SST)      ✓ keep
#    102     2.8637    -2.8637  ψSaSSψSSSS  ψ₁(Anc×SST)      ✓ keep
#    103     2.8494    -2.8494     sin(TS)  Anchovy          ✓ keep
#    104     2.7786    +2.7786  ψAnSSψSaSS  Sardine          ✓ keep
#    105     2.7509    -2.7509  ψAnSSψSaSS  Anchovy          ✓ keep
#    106     2.7459    +2.7459      cos(a)  Sardine          ✓ keep
#    107     2.7383    +2.7383  cos(ψSaSS)  ψ₁(Sar×SST)      ✓ keep
#    108     2.7236    -2.7236      sψAnSS  SST_SIO          ✓ keep
#    109     2.7092    +2.7092     sin(TS)  ψ₁(Anc×SST)      ✓ keep
#    110     2.7026    +2.7026       ψSaSS  ψ₁(Sar×SST)      ✓ keep
#    111     2.7014    -2.7014      sin(s)  ψ₁(Anc×Sar)      ✓ keep
#    112     2.6856    +2.6856  ψAnSSψSSSS  ψ₁(Sar×SST)      ✓ keep
#    113     2.6770    +2.6770     TSψSaSS  ψ₁(Sar×SST)      ✓ keep
#    114     2.6684    -2.6684     TSψAnSS  SST_SIO          ✓ keep
#    115     2.6639    -2.6639  sin(ψSaSS)  ψ₁(Anc×SST)      ✓ keep
#    116     2.6525    -2.6525      sψAnSS  Sardine          ✓ keep
#    117     2.6524    +2.6524         sTS  ψ₁(Anc×Sar)      ✓ keep
#    118     2.6452    -2.6452  cos(ψSaSS)  SST_NP           ✓ keep
#    119     2.6412    -2.6412          TS  ψ₁(Anc×SST)      ✓ keep
#    120     2.6375    -2.6375  cos(ψAnSa)  ψ₁(Anc×SST)      ✓ keep
#    121     2.6267    +2.6267  cos(ψAnSS)  ψ₁(Sar×SST)      ✓ keep
#    122     2.5934    +2.5934     TNψAnSS  Sardine          ✓ keep
#    123     2.5773    +2.5773  ψAnSaψAnSa  SST_NP           ✓ keep
#    124     2.5686    -2.5686  ψAnSSψAnSS  Anchovy          ✓ keep
#    125     2.5431    -2.5431         sTS  Sardine          ✓ keep
#    126     2.5359    -2.5359  ψAnSSψAnSS  SST_NP           ✓ keep
#    127     2.5345    -2.5345  cos(ψAnSa)  ψ₁(Sar×SST)      ✓ keep
#    128     2.5117    +2.5117      aψAnSa  Sardine          ✓ keep
#    129     2.5112    -2.5112      aψSaSS  ψ₁(Sar×SST)      ✓ keep
#    130     2.5105    -2.5105  ψAnSSψSSSS  SST_NP           ✓ keep
#    131     2.5018    +2.5018           s  ψ₁(Anc×Sar)      ✓ keep
#    132     2.4897    +2.4897     cos(TN)  SST_NP           ✓ keep
#    133     2.4812    -2.4812  ψAnSSψSSSS  SST_NP           ✓ keep
#    134     2.4785    +2.4785     TNψAnSS  ψ₁(Sar×SST)      ✓ keep
#    135     2.4693    +2.4693     TSψSSSS  ψ₁(Sar×SST)      ✓ keep
#    136     2.4643    +2.4643  ψAnSSψAnSS  ψ₁(Sar×SST)      ✓ keep
#    137     2.4457    +2.4457      sψAnSS  ψ₁(Sar×SST)      ✓ keep
#    138     2.4232    +2.4232     cos(TS)  SST_NP           ✓ keep
#    139     2.4169    -2.4169      sψAnSa  Sardine          ✓ keep
#    140     2.4053    +2.4053     TSψAnSa  Sardine          ✓ keep
#    141     2.3923    +2.3923       ψAnSS  Anchovy          ✓ keep
#    142     2.3675    -2.3675      aψAnSS  SST_SIO          ✓ keep
#    143     2.3657    -2.3657     TNψSaSS  ψ₁(Anc×SST)      ✓ keep
#    144     2.3632    -2.3632         aTN  Anchovy          ✓ keep
#    145     2.3607    +2.3607      sψSaSS  SST_NP           ✓ keep
#    146     2.3599    -2.3599  sin(ψSSSS)  ψ₁(Sar×SST)      ✓ keep
#    147     2.3587    -2.3587  ψSaSSψSSSS  Sardine          ✓ keep
#    148     2.3517    -2.3517           s  ψ₁(Sar×SST)      ✓ keep
#    149     2.3126    -2.3126  ψAnSSψAnSS  ψ₁(Sar×SST)      ✓ keep
#    150     2.3087    -2.3087  ψAnSSψSSSS  SST_SIO          ✓ keep
#    151     2.3084    +2.3084     sin(TS)  SST_NP           ✓ keep
#    152     2.3076    -2.3076  cos(ψSaSS)  ψ₁(SST×SST)      ✓ keep
#    153     2.2832    +2.2832     TSψSaSS  SST_SIO          ✓ keep
#    154     2.2814    -2.2814         aTN  ψ₁(Sar×SST)      ✓ keep
#    155     2.2802    +2.2802     TSψSaSS  ψ₁(Anc×SST)      ✓ keep
#    156     2.2686    +2.2686  ψSaSSψSSSS  ψ₁(Anc×SST)      ✓ keep
#    157     2.2637    -2.2637  ψSaSSψSaSS  ψ₁(Anc×SST)      ✓ keep
#    158     2.2438    -2.2438  ψSSSSψSSSS  SST_NP           ✓ keep
#    159     2.2388    -2.2388     TSψAnSS  Sardine          ✓ keep
#    160     2.2126    +2.2126        TSTN  SST_NP           ✓ keep
#    161     2.2123    -2.2123          ss  SST_NP           ✓ keep
#    162     2.1975    +2.1975         sTN  Sardine          ✓ keep
#    163     2.1842    -2.1842  sin(ψSaSS)  Anchovy          ✓ keep
#    164     2.1745    +2.1745  ψSaSSψSaSS  ψ₁(Anc×SST)      ✓ keep
#    165     2.1742    -2.1742  ψAnSSψSaSS  Anchovy          ✓ keep
#    166     2.1663    +2.1663          TS  Anchovy          ✓ keep
#    167     2.1520    -2.1520         sTN  SST_NP           ✓ keep
#    168     2.1458    -2.1458           1  SST_NP           ✓ keep
#    169     2.1348    +2.1348       ψSSSS  SST_SIO          ✓ keep
#    170     2.1306    +2.1306          TN  ψ₁(Sar×SST)      ✓ keep
#    171     2.1277    -2.1277  cos(ψSSSS)  Sardine          ✓ keep
#    172     2.1243    +2.1243  sin(ψSaSS)  ψ₁(Anc×SST)      ✓ keep
#    173     2.1189    -2.1189  cos(ψSaSS)  SST_SIO          ✓ keep
#    174     2.1005    +2.1005     TNψAnSS  ψ₁(Anc×Sar)      ✓ keep
#    175     2.0943    -2.0943  ψSaSSψSaSS  Anchovy          ✓ keep
#    176     2.0934    -2.0934  ψAnSSψAnSS  SST_SIO          ✓ keep
#    177     2.0928    -2.0928      sψSaSS  ψ₁(Sar×SST)      ✓ keep
#    178     2.0885    -2.0885  ψAnSSψAnSS  ψ₁(SST×SST)      ✓ keep
#    179     2.0836    -2.0836  ψAnSSψSSSS  Sardine          ✓ keep
#    180     2.0785    -2.0785     sin(TS)  ψ₁(Anc×SST)      ✓ keep
#    181     2.0717    +2.0717  ψSaSSψSSSS  SST_SIO          ✓ keep
#    182     2.0684    +2.0684  ψSaSSψSaSS  SST_SIO          ✓ keep
#    183     2.0672    +2.0672     TNψSaSS  ψ₁(Anc×SST)      ✓ keep
#    184     2.0607    -2.0607  ψAnSSψAnSS  SST_NP           ✓ keep
#    185     2.0472    +2.0472  sin(ψSSSS)  ψ₁(Sar×SST)      ✓ keep
#    186     2.0430    -2.0430  ψAnSSψAnSS  SST_SIO          ✓ keep
#    187     2.0344    -2.0344        TSTN  Sardine          ✓ keep
#    188     2.0237    +2.0237  cos(ψSSSS)  ψ₁(Sar×SST)      ✓ keep
#    189     2.0059    -2.0059     TNψSSSS  Anchovy          ✓ keep
#    190     2.0058    -2.0058        TSTN  Anchovy          ✓ keep
#    191     1.9920    -1.9920  ψSaSSψSSSS  ψ₁(SST×SST)      ✓ keep
#    192     1.9916    -1.9916     TSψAnSS  Anchovy          ✓ keep
#    193     1.9812    -1.9812  cos(ψAnSS)  ψ₁(SST×SST)      ✓ keep
#    194     1.9736    +1.9736      aψSaSS  Sardine          ✓ keep
#    195     1.9645    +1.9645           a  ψ₁(Sar×SST)      ✓ keep
#    196     1.9609    +1.9609  ψSaSSψSSSS  ψ₁(Sar×SST)      ✓ keep
#    197     1.9546    +1.9546      sψSaSS  SST_SIO          ✓ keep
#    198     1.9391    +1.9391  ψSaSSψSSSS  ψ₁(Sar×SST)      ✓ keep
#    199     1.9295    +1.9295     TSψSaSS  SST_NP           ✓ keep
#    200     1.9276    -1.9276        TSTN  ψ₁(Sar×SST)      ✓ keep
#    201     1.9106    +1.9106          ss  Anchovy          ✓ keep
#    202     1.9075    +1.9075  ψSaSSψSSSS  ψ₁(Anc×SST)      ✓ keep
#    203     1.9034    -1.9034  ψAnSSψAnSS  ψ₁(SST×SST)      ✓ keep
#    204     1.8816    -1.8816      cos(a)  ψ₁(Sar×SST)      ✓ keep
#    205     1.8804    +1.8804     TSψAnSa  Anchovy          ✓ keep
#    206     1.8748    -1.8748      sψSaSS  ψ₁(Sar×SST)      ✓ keep
#    207     1.8639    +1.8639  ψAnSSψAnSS  ψ₁(Anc×SST)      ✓ keep
#    208     1.8620    +1.8620  ψSaSSψSSSS  ψ₁(Anc×Sar)      ✓ keep
#    209     1.8572    +1.8572      sψSSSS  ψ₁(Sar×SST)      ✓ keep
#    210     1.8488    -1.8488         sTS  ψ₁(Anc×SST)      ✓ keep
#    211     1.8450    -1.8450      sψAnSa  Anchovy          ✓ keep
#    212     1.8374    +1.8374  sin(ψAnSS)  ψ₁(SST×SST)      ✓ keep
#    213     1.8327    -1.8327  sin(ψSSSS)  Anchovy          ✓ keep
#    214     1.8294    -1.8294         sTN  SST_SIO          ✓ keep
#    215     1.8182    -1.8182      sψSaSS  Anchovy          ✓ keep
#    216     1.8177    +1.8177       ψAnSS  Sardine          ✓ keep
#    217     1.8151    +1.8151      aψAnSS  Sardine          ✓ keep
#    218     1.8093    -1.8093  ψSaSSψSaSS  Anchovy          ✓ keep
#    219     1.8006    -1.8006      aψAnSS  ψ₁(Anc×SST)      ✓ keep
#    220     1.7966    +1.7966      aψAnSS  SST_NP           ✓ keep
#    221     1.7892    +1.7892  ψAnSSψAnSS  Anchovy          ✓ keep
#    222     1.7791    -1.7791     TSψSaSS  SST_NP           ✓ keep
#    223     1.7775    -1.7775     TNψSSSS  Sardine          ✓ keep
#    224     1.7745    -1.7745  ψAnSSψAnSS  ψ₁(Anc×SST)      ✓ keep
#    225     1.7685    +1.7685     TNψAnSS  ψ₁(Anc×SST)      ✓ keep
#    226     1.7628    +1.7628         aTS  Anchovy          ✓ keep
#    227     1.7576    +1.7576     cos(TN)  ψ₁(Anc×SST)      ✓ keep
#    228     1.7553    -1.7553  ψSSSSψSSSS  SST_SIO          ✓ keep
#    229     1.7502    -1.7502     TNψSaSS  Sardine          ✓ keep
#    230     1.7498    +1.7498      aψSSSS  SST_NP           ✓ keep
#    231     1.7494    -1.7494      cos(s)  ψ₁(Anc×Sar)      ✓ keep
#    232     1.7483    -1.7483     TNψSaSS  ψ₁(Anc×Sar)      ✓ keep
#    233     1.7442    -1.7442     sin(TN)  ψ₁(Sar×SST)      ✓ keep
#    234     1.7386    -1.7386  ψAnSSψSaSS  ψ₁(Anc×SST)      ✓ keep
#    235     1.7302    +1.7302     TNψSSSS  SST_NP           ✓ keep
#    236     1.7126    -1.7126         aTS  Sardine          ✓ keep
#    237     1.7125    -1.7125      sψAnSS  Sardine          ✓ keep
#    238     1.7071    -1.7071      aψSSSS  ψ₁(Sar×SST)      ✓ keep
#    239     1.7063    -1.7063  cos(ψSSSS)  SST_SIO          ✓ keep
#    240     1.7020    -1.7020  ψAnSSψAnSS  ψ₁(Sar×SST)      ✓ keep
#    241     1.6952    -1.6952  cos(ψAnSS)  ψ₁(Anc×SST)      ✓ keep
#    242     1.6914    +1.6914     TNψSaSS  ψ₁(Anc×SST)      ✓ keep
#    243     1.6801    +1.6801  cos(ψAnSS)  ψ₁(Anc×SST)      ✓ keep
#    244     1.6687    -1.6687       ψSSSS  Anchovy          ✓ keep
#    245     1.6628    -1.6628     sin(TS)  ψ₁(Anc×Sar)      ✓ keep
#    246     1.6565    +1.6565      sψSaSS  ψ₁(Anc×Sar)      ✓ keep
#    247     1.6550    +1.6550       ψAnSS  ψ₁(Sar×SST)      ✓ keep
#    248     1.6527    -1.6527         aTN  ψ₁(Anc×Sar)      ✓ keep
#    249     1.6520    +1.6520          TS  ψ₁(Anc×Sar)      ✓ keep
#    250     1.6481    -1.6481  sin(ψAnSS)  ψ₁(Anc×SST)      ✓ keep
#    251     1.6480    -1.6480     TNψSaSS  SST_NP           ✓ keep
#    252     1.6450    -1.6450     TSψSaSS  ψ₁(Anc×SST)      ✓ keep
#    253     1.6402    +1.6402  ψAnSaψSaSS  ψ₁(Sar×SST)      ✓ keep
#    254     1.6380    -1.6380  ψAnSaψAnSa  ψ₁(Anc×SST)      ✓ keep
#    255     1.6263    +1.6263     TNψSaSS  SST_NP           ✓ keep
#    256     1.6140    -1.6140           s  ψ₁(Anc×SST)      ✓ keep
#    257     1.6119    +1.6119  ψAnSaψAnSS  Sardine          ✓ keep
#    258     1.6100    +1.6100  ψSaSSψSaSS  SST_SIO          ✓ keep
#    259     1.6083    +1.6083       ψAnSa  ψ₁(Sar×SST)
#    260     1.5909    +1.5909  ψAnSSψAnSS  SST_NP
#    261     1.5879    +1.5879     sin(TN)  Sardine
#    262     1.5791    -1.5791     cos(TN)  ψ₁(Sar×SST)
#    263     1.5734    +1.5734     TNψAnSS  SST_NP
#    264     1.5730    -1.5730  ψAnSSψAnSS  ψ₁(Anc×Sar)
#    265     1.5716    +1.5716        TNTN  Sardine
#    266     1.5699    -1.5699      sψAnSS  ψ₁(Anc×Sar)
#    267     1.5679    +1.5679          TS  ψ₁(Anc×SST)
#    268     1.5665    -1.5665     TNψSaSS  SST_SIO
#    269     1.5653    -1.5653  ψAnSSψSaSS  ψ₁(Sar×SST)
#    270     1.5638    +1.5638      aψAnSa  ψ₁(Sar×SST)
#    271     1.5579    +1.5579  ψAnSaψAnSS  Anchovy
#    272     1.5478    -1.5478  ψSaSSψSSSS  ψ₁(Anc×SST)
#    273     1.5454    -1.5454       ψSaSS  ψ₁(Anc×Sar)
#    274     1.5432    +1.5432      sin(s)  ψ₁(Anc×SST)
#    275     1.5406    -1.5406        TSTS  ψ₁(Anc×Sar)
#    276     1.5371    +1.5371         sTN  Anchovy
#    277     1.5363    +1.5363     sin(TS)  SST_SIO
#    278     1.5293    -1.5293        TSTS  Sardine
#    279     1.5261    +1.5261        TSTS  ψ₁(Sar×SST)
#    280     1.5237    -1.5237     TNψSaSS  ψ₁(Anc×SST)
#    281     1.5151    +1.5151      aψSSSS  ψ₁(Sar×SST)
#    282     1.5143    -1.5143  ψAnSSψSaSS  ψ₁(Anc×SST)
#    283     1.5124    +1.5124     TSψAnSS  Sardine
#    284     1.5097    -1.5097          TS  ψ₁(Sar×SST)
#    285     1.5075    -1.5075     TNψSaSS  ψ₁(Anc×Sar)
#    286     1.5068    -1.5068     TNψAnSa  Sardine
#    287     1.5066    -1.5066           a  SST_NP
#    288     1.5019    -1.5019  ψAnSaψAnSS  SST_SIO
#    289     1.4947    +1.4947      aψSSSS  ψ₁(Anc×Sar)
#    290     1.4928    +1.4928      sψSSSS  Anchovy
#    291     1.4869    -1.4869     sin(TS)  Sardine
#    292     1.4807    -1.4807      sψAnSa  ψ₁(Sar×SST)
#    293     1.4769    -1.4769     TSψSaSS  ψ₁(Sar×SST)
#    294     1.4765    -1.4765       ψSSSS  ψ₁(Sar×SST)
#    295     1.4733    -1.4733  ψAnSaψSSSS  Anchovy
#    296     1.4716    -1.4716  ψSaSSψSaSS  Sardine
#    297     1.4669    -1.4669  sin(ψAnSa)  ψ₁(Anc×SST)
#    298     1.4562    +1.4562  sin(ψAnSS)  ψ₁(Sar×SST)
#    299     1.4452    +1.4452  sin(ψSaSS)  ψ₁(Sar×SST)
#    300     1.4414    -1.4414  ψAnSaψAnSa  ψ₁(Sar×SST)
#    301     1.4362    -1.4362     TNψSaSS  Anchovy
#    302     1.4277    -1.4277     TNψAnSa  ψ₁(Sar×SST)
#    303     1.4240    -1.4240      aψSaSS  ψ₁(Anc×Sar)
#    304     1.4166    -1.4166      aψAnSS  ψ₁(Sar×SST)
#    305     1.4093    +1.4093        TSTN  SST_SIO
#    306     1.4091    +1.4091  ψAnSSψAnSS  Anchovy
#    307     1.4066    +1.4066       ψSaSS  ψ₁(Anc×SST)
#    308     1.4059    +1.4059         aTN  SST_SIO
#    309     1.4048    +1.4048  ψSaSSψSaSS  SST_NP
#    310     1.4039    +1.4039  ψAnSaψAnSa  ψ₁(Anc×SST)
#    311     1.4027    +1.4027        TSTS  SST_SIO
#    312     1.3971    -1.3971     TNψAnSS  ψ₁(Sar×SST)
#    313     1.3897    -1.3897      aψAnSS  SST_NP
#    314     1.3893    -1.3893  cos(ψAnSa)  ψ₁(Anc×Sar)
#    315     1.3820    +1.3820         aTN  ψ₁(Sar×SST)
#    316     1.3777    +1.3777      aψAnSS  ψ₁(SST×SST)
#    317     1.3717    -1.3717     cos(TS)  Sardine
#    318     1.3715    +1.3715  cos(ψAnSS)  ψ₁(Sar×SST)
#    319     1.3712    -1.3712     TSψSSSS  Sardine
#    320     1.3565    -1.3565           a  ψ₁(Sar×SST)
#    321     1.3520    +1.3520     TNψSaSS  ψ₁(Sar×SST)
#    322     1.3438    +1.3438           s  ψ₁(Anc×SST)
#    323     1.3425    -1.3425  ψAnSSψSaSS  ψ₁(Anc×SST)
#    324     1.3413    -1.3413  ψSaSSψSaSS  SST_SIO
#    325     1.3394    -1.3394      aψAnSS  ψ₁(Sar×SST)
#    326     1.3361    -1.3361  ψAnSSψSSSS  ψ₁(Anc×SST)
#    327     1.3299    -1.3299     TNψAnSS  ψ₁(Anc×SST)
#    328     1.3270    -1.3270     TNψSaSS  ψ₁(Sar×SST)
#    329     1.3260    +1.3260     TNψAnSS  SST_SIO
#    330     1.3248    -1.3248  cos(ψSaSS)  Sardine
#    331     1.3155    -1.3155          ss  SST_SIO
#    332     1.3138    +1.3138  ψAnSSψSaSS  ψ₁(Anc×SST)
#    333     1.3130    +1.3130  ψAnSSψAnSS  SST_SIO
#    334     1.3101    -1.3101     TSψAnSS  ψ₁(Anc×Sar)
#    335     1.3071    +1.3071      aψSaSS  Anchovy
#    336     1.3024    -1.3024         sTN  ψ₁(Anc×Sar)
#    337     1.2965    -1.2965          ss  Sardine
#    338     1.2951    +1.2951  sin(ψAnSS)  ψ₁(Anc×SST)
#    339     1.2911    +1.2911      sψAnSa  ψ₁(Anc×Sar)
#    340     1.2878    +1.2878       ψSaSS  ψ₁(Sar×SST)
#    341     1.2822    +1.2822         aTN  Sardine
#    342     1.2766    +1.2766  ψAnSaψAnSa  SST_SIO
#    343     1.2747    -1.2747  ψAnSSψAnSS  ψ₁(Anc×Sar)
#    344     1.2723    -1.2723  cos(ψSSSS)  ψ₁(Anc×Sar)
#    345     1.2576    +1.2576  ψAnSSψSaSS  ψ₁(Anc×SST)
#    346     1.2554    +1.2554         aTN  ψ₁(Anc×SST)
#    347     1.2486    +1.2486  ψAnSaψAnSS  Sardine
#    348     1.2409    -1.2409        TSTS  ψ₁(Sar×SST)
#    349     1.2389    +1.2389  ψAnSSψSSSS  ψ₁(Sar×SST)
#    350     1.2357    -1.2357  ψAnSSψSaSS  SST_SIO
#    351     1.2258    +1.2258  ψAnSSψAnSS  ψ₁(Anc×SST)
#    352     1.2258    -1.2258     cos(TN)  ψ₁(Sar×SST)
#    353     1.2189    +1.2189     TNψSaSS  SST_SIO
#    354     1.2170    -1.2170  ψAnSaψSaSS  SST_SIO
#    355     1.2164    +1.2164  sin(ψSaSS)  Sardine
#    356     1.2153    -1.2153       ψAnSS  SST_SIO
#    357     1.2150    +1.2150        TSTS  ψ₁(Anc×SST)
#    358     1.2006    +1.2006         sTS  ψ₁(Sar×SST)
#    359     1.2003    +1.2003  ψAnSSψSaSS  SST_NP
#    360     1.2003    +1.2003  ψAnSSψAnSS  ψ₁(Sar×SST)
#    361     1.1989    -1.1989       ψSaSS  ψ₁(Anc×SST)
#    362     1.1849    +1.1849  ψAnSSψSaSS  Sardine
#    363     1.1838    +1.1838       ψSaSS  Anchovy
#    364     1.1797    -1.1797      aψSaSS  SST_NP
#    365     1.1699    +1.1699  ψAnSaψSSSS  SST_SIO
#    366     1.1678    +1.1678  sin(ψSaSS)  ψ₁(Sar×SST)
#    367     1.1562    +1.1562  ψAnSaψAnSS  SST_NP
#    368     1.1457    +1.1457     sin(TN)  ψ₁(Anc×SST)
#    369     1.1345    +1.1345      aψAnSS  ψ₁(Anc×Sar)
#    370     1.1342    +1.1342     TNψSaSS  ψ₁(SST×SST)
#    371     1.1260    -1.1260      aψAnSa  ψ₁(Sar×SST)
#    372     1.1252    -1.1252  ψAnSaψSaSS  SST_NP
#    373     1.1214    +1.1214         sTS  ψ₁(Anc×SST)
#    374     1.1186    -1.1186     TSψSSSS  SST_NP
#    375     1.1182    +1.1182         sTN  ψ₁(Anc×SST)
#    376     1.1129    +1.1129  ψAnSaψAnSa  Sardine
#    377     1.1024    +1.1024  ψAnSSψSaSS  SST_NP
#    378     1.1007    -1.1007       ψSaSS  Sardine
#    379     1.0995    -1.0995      cos(s)  ψ₁(SST×SST)
#    380     1.0970    -1.0970           1  SST_SIO
#    381     1.0922    +1.0922  ψAnSSψSaSS  ψ₁(Sar×SST)
#    382     1.0920    +1.0920          TS  SST_SIO
#    383     1.0916    -1.0916        TSTS  ψ₁(Anc×SST)
#    384     1.0889    -1.0889          as  Anchovy
#    385     1.0877    -1.0877           1  ψ₁(Anc×Sar)
#    386     1.0848    -1.0848       ψSaSS  SST_NP
#    387     1.0805    +1.0805  cos(ψSaSS)  ψ₁(Sar×SST)
#    388     1.0750    +1.0750      aψSaSS  ψ₁(Sar×SST)
#    389     1.0745    -1.0745      aψSSSS  Sardine
#    390     1.0734    -1.0734  ψAnSaψSSSS  Sardine
#    391     1.0722    -1.0722  ψSaSSψSaSS  ψ₁(Sar×SST)
#    392     1.0602    -1.0602      aψAnSS  ψ₁(Anc×SST)
#    393     1.0548    -1.0548  sin(ψAnSS)  ψ₁(Sar×SST)
#    394     1.0534    -1.0534           a  ψ₁(Anc×Sar)
#    395     1.0487    -1.0487     TNψAnSS  Anchovy
#    396     1.0433    +1.0433     TSψAnSa  ψ₁(Anc×SST)
#    397     1.0392    -1.0392  sin(ψSaSS)  ψ₁(Sar×SST)
#    398     1.0299    -1.0299  ψAnSaψAnSS  ψ₁(Anc×Sar)
#    399     1.0196    +1.0196      sψAnSS  Anchovy
#    400     1.0178    -1.0178     TSψAnSS  ψ₁(Sar×SST)
#    401     1.0159    -1.0159  ψAnSSψAnSS  ψ₁(Anc×SST)
#    402     1.0148    -1.0148       ψSaSS  ψ₁(Sar×SST)
#    403     1.0146    +1.0146     cos(TS)  ψ₁(Sar×SST)
#    404     1.0139    +1.0139  ψAnSSψSaSS  Anchovy
#    405     1.0082    +1.0082         aTS  ψ₁(Sar×SST)
#    406     1.0039    +1.0039      sψAnSS  ψ₁(Sar×SST)
#    407     1.0039    -1.0039          TS  ψ₁(SST×SST)
#    408     1.0028    -1.0028     TSψSaSS  ψ₁(Anc×SST)
#    409     0.9999    -0.9999     TNψAnSa  ψ₁(Anc×SST)
#    410     0.9951    -0.9951  ψAnSSψAnSS  Sardine
#    411     0.9914    -0.9914      sψSaSS  ψ₁(Anc×SST)
#    412     0.9893    +0.9893  ψAnSaψSSSS  ψ₁(Anc×SST)
#    413     0.9889    +0.9889  sin(ψAnSS)  SST_SIO
#    414     0.9889    +0.9889           1  ψ₁(SST×SST)
#    415     0.9884    -0.9884      cos(a)  Anchovy
#    416     0.9845    +0.9845       ψSSSS  ψ₁(Anc×Sar)
#    417     0.9837    -0.9837      sψSSSS  ψ₁(Anc×SST)
#    418     0.9796    -0.9796  sin(ψAnSa)  ψ₁(Sar×SST)
#    419     0.9746    +0.9746  ψSaSSψSaSS  ψ₁(Anc×Sar)
#    420     0.9626    +0.9626     cos(TN)  SST_SIO
#    421     0.9610    +0.9610  sin(ψAnSa)  SST_NP
#    422     0.9609    -0.9609  ψAnSaψSaSS  ψ₁(Anc×Sar)
#    423     0.9534    -0.9534     TNψAnSS  Sardine
#    424     0.9531    -0.9531     cos(TS)  ψ₁(Sar×SST)
#    425     0.9496    +0.9496     TNψAnSa  ψ₁(Anc×SST)
#    426     0.9476    -0.9476  ψAnSaψSSSS  ψ₁(Anc×SST)
#    427     0.9467    -0.9467  ψAnSaψSaSS  Anchovy
#    428     0.9441    +0.9441     sin(TS)  ψ₁(SST×SST)
#    429     0.9429    +0.9429          TS  Sardine
#    430     0.9427    +0.9427  cos(ψAnSS)  ψ₁(Sar×SST)
#    431     0.9411    +0.9411  ψAnSSψAnSS  ψ₁(Sar×SST)
#    432     0.9389    +0.9389     TNψSSSS  SST_SIO
#    433     0.9348    -0.9348          TN  ψ₁(Anc×SST)
#    434     0.9313    +0.9313     TNψAnSS  ψ₁(Sar×SST)
#    435     0.9294    -0.9294  sin(ψAnSS)  Sardine
#    436     0.9279    -0.9279  ψAnSSψSaSS  ψ₁(Anc×Sar)
#    437     0.9195    +0.9195        TNTN  ψ₁(Anc×SST)
#    438     0.9178    -0.9178          TN  SST_NP
#    439     0.9157    +0.9157     TSψSSSS  ψ₁(Anc×SST)
#    440     0.9146    -0.9146       ψAnSS  ψ₁(SST×SST)
#    441     0.9124    -0.9124          TN  Sardine
#    442     0.9118    -0.9118        TNTN  Anchovy
#    443     0.9102    -0.9102  cos(ψAnSS)  Sardine
#    444     0.9066    -0.9066          TN  ψ₁(Anc×Sar)
#    445     0.9012    -0.9012  sin(ψAnSS)  SST_SIO
#    446     0.9008    -0.9008          TN  SST_SIO
#    447     0.8945    +0.8945     TNψAnSS  Anchovy
#    448     0.8916    -0.8916       ψAnSa  SST_SIO
#    449     0.8888    +0.8888      cos(a)  ψ₁(SST×SST)
#    450     0.8796    -0.8796      aψSaSS  SST_NP
#    451     0.8709    -0.8709       ψAnSa  SST_NP
#    452     0.8688    -0.8688      sin(a)  SST_SIO
#    453     0.8665    +0.8665       ψAnSS  ψ₁(Sar×SST)
#    454     0.8629    +0.8629  ψAnSSψAnSS  ψ₁(Anc×Sar)
#    455     0.8527    -0.8527     TSψAnSS  ψ₁(SST×SST)
#    456     0.8526    -0.8526        TNTN  ψ₁(Anc×SST)
#    457     0.8506    -0.8506      sψAnSS  ψ₁(Anc×Sar)
#    458     0.8464    +0.8464          as  SST_NP
#    459     0.8421    +0.8421       ψAnSS  ψ₁(SST×SST)
#    460     0.8420    -0.8420     TSψSaSS  ψ₁(Sar×SST)
#    461     0.8369    -0.8369     sin(TS)  ψ₁(Sar×SST)
#    462     0.8317    +0.8317     cos(TS)  Anchovy
#    463     0.8310    -0.8310        TNTN  ψ₁(Sar×SST)
#    464     0.8304    +0.8304          TN  ψ₁(Anc×SST)
#    465     0.8302    -0.8302         sTN  ψ₁(Anc×SST)
#    466     0.8284    +0.8284  ψAnSSψSaSS  SST_NP
#    467     0.8279    +0.8279        TSTS  ψ₁(SST×SST)
#    468     0.8271    +0.8271  ψAnSaψSaSS  Anchovy
#    469     0.8219    -0.8219  ψSaSSψSaSS  Sardine
#    470     0.8161    -0.8161      sψAnSa  ψ₁(Sar×SST)
#    471     0.8144    +0.8144     TSψSaSS  ψ₁(Anc×SST)
#    472     0.8110    -0.8110  ψAnSSψSSSS  ψ₁(SST×SST)
#    473     0.8107    -0.8107  sin(ψSaSS)  SST_SIO
#    474     0.8083    -0.8083      sψAnSS  ψ₁(Sar×SST)
#    475     0.8082    -0.8082  ψAnSaψSaSS  SST_NP
#    476     0.8059    +0.8059     sin(TN)  Anchovy
#    477     0.8035    -0.8035       ψAnSS  SST_NP
#    478     0.8001    +0.8001  sin(ψAnSa)  ψ₁(SST×SST)
#    479     0.7992    -0.7992      sin(s)  ψ₁(Anc×SST)
#    480     0.7898    -0.7898           1  ψ₁(Sar×SST)
#    481     0.7893    -0.7893     TNψAnSS  ψ₁(SST×SST)
#    482     0.7878    -0.7878     TSψAnSS  ψ₁(Sar×SST)
#    483     0.7864    +0.7864      cos(a)  ψ₁(Sar×SST)
#    484     0.7863    +0.7863       ψSaSS  ψ₁(Anc×SST)
#    485     0.7822    +0.7822      sψAnSS  ψ₁(SST×SST)
#    486     0.7773    +0.7773      cos(s)  ψ₁(Anc×SST)
#    487     0.7751    -0.7751      sψAnSS  ψ₁(Anc×SST)
#    488     0.7746    -0.7746     TNψSaSS  ψ₁(Sar×SST)
#    489     0.7721    -0.7721  ψAnSSψAnSS  ψ₁(Sar×SST)
#    490     0.7634    -0.7634       ψSSSS  ψ₁(Anc×SST)
#    491     0.7605    +0.7605      aψSaSS  SST_SIO
#    492     0.7603    +0.7603      aψSaSS  ψ₁(SST×SST)
#    493     0.7532    +0.7532      sψSaSS  ψ₁(Sar×SST)
#    494     0.7512    +0.7512        TNTN  ψ₁(SST×SST)
#    495     0.7483    -0.7483      cos(a)  SST_NP
#    496     0.7482    +0.7482  ψAnSSψSSSS  ψ₁(Sar×SST)
#    497     0.7480    +0.7480     TSψAnSS  ψ₁(Anc×SST)
#    498     0.7456    -0.7456         aTS  ψ₁(Anc×SST)
#    499     0.7436    -0.7436      sψSaSS  Anchovy
#    500     0.7431    -0.7431  ψAnSaψAnSS  ψ₁(Sar×SST)
#    501     0.7385    +0.7385         sTN  ψ₁(Sar×SST)
#    502     0.7343    -0.7343     TNψSSSS  ψ₁(SST×SST)
#    503     0.7325    -0.7325        TNTN  ψ₁(Anc×Sar)
#    504     0.7291    +0.7291          aa  Sardine
#    505     0.7286    +0.7286       ψSaSS  SST_SIO
#    506     0.7232    +0.7232        TNTN  ψ₁(Sar×SST)
#    507     0.7225    -0.7225     TSψSSSS  ψ₁(Sar×SST)
#    508     0.7196    -0.7196  sin(ψSSSS)  ψ₁(SST×SST)
#    509     0.7178    -0.7178     TSψAnSa  ψ₁(Anc×SST)
#    510     0.7159    +0.7159      sψAnSS  ψ₁(Anc×SST)
#    511     0.7137    +0.7137          TS  SST_NP
#    512     0.7122    -0.7122     TSψAnSS  ψ₁(SST×SST)
#    513     0.6865    -0.6865      aψSSSS  ψ₁(Anc×SST)
#    514     0.6811    -0.6811      sψAnSS  SST_NP
#    515     0.6757    +0.6757     TNψSaSS  Sardine
#    516     0.6748    +0.6748  cos(ψSaSS)  ψ₁(Sar×SST)
#    517     0.6743    -0.6743     sin(TS)  ψ₁(Sar×SST)
#    518     0.6729    +0.6729      aψAnSS  ψ₁(Anc×SST)
#    519     0.6700    +0.6700      sin(a)  Anchovy
#    520     0.6699    -0.6699         sTN  ψ₁(Sar×SST)
#    521     0.6675    -0.6675           1  Sardine
#    522     0.6665    +0.6665  cos(ψSSSS)  Anchovy
#    523     0.6613    -0.6613          aa  ψ₁(Sar×SST)
#    524     0.6599    -0.6599  ψAnSSψSaSS  ψ₁(Anc×SST)
#    525     0.6545    -0.6545  sin(ψAnSS)  ψ₁(Anc×Sar)
#    526     0.6536    +0.6536         aTS  ψ₁(Anc×SST)
#    527     0.6533    +0.6533           a  ψ₁(Anc×SST)
#    528     0.6519    -0.6519     cos(TN)  ψ₁(Anc×Sar)
#    529     0.6498    +0.6498     sin(TN)  ψ₁(SST×SST)
#    530     0.6498    -0.6498  ψAnSaψSSSS  ψ₁(Sar×SST)
#    531     0.6421    -0.6421  ψSaSSψSSSS  ψ₁(Sar×SST)
#    532     0.6397    -0.6397       ψAnSS  ψ₁(Sar×SST)
#    533     0.6392    +0.6392  ψAnSSψSaSS  ψ₁(Anc×Sar)
#    534     0.6350    +0.6350      aψSaSS  Anchovy
#    535     0.6309    -0.6309      sin(a)  ψ₁(Anc×SST)
#    536     0.6302    +0.6302  ψAnSaψAnSS  ψ₁(Anc×SST)
#    537     0.6248    +0.6248         aTS  ψ₁(Anc×Sar)
#    538     0.6232    +0.6232     TNψAnSS  ψ₁(SST×SST)
#    539     0.6226    -0.6226         sTS  ψ₁(SST×SST)
#    540     0.6215    +0.6215      aψAnSa  ψ₁(SST×SST)
#    541     0.6212    -0.6212      aψAnSa  SST_NP
#    542     0.6202    -0.6202  ψSaSSψSaSS  ψ₁(Sar×SST)
#    543     0.6187    +0.6187       ψSaSS  ψ₁(SST×SST)
#    544     0.6175    +0.6175  ψAnSSψSSSS  Anchovy
#    545     0.6150    +0.6150      sψSaSS  ψ₁(Anc×SST)
#    546     0.6132    +0.6132  sin(ψAnSS)  Anchovy
#    547     0.6115    -0.6115  ψSSSSψSSSS  Sardine
#    548     0.6112    -0.6112  ψAnSaψSaSS  ψ₁(Sar×SST)
#    549     0.6102    +0.6102          ss  ψ₁(Sar×SST)
#    550     0.6081    -0.6081  sin(ψAnSS)  ψ₁(Anc×Sar)
#    551     0.6052    +0.6052      sψSaSS  ψ₁(Anc×Sar)
#    552     0.6050    -0.6050  ψAnSaψSaSS  ψ₁(Anc×SST)
#    553     0.6041    +0.6041     TNψSaSS  Anchovy
#    554     0.6012    -0.6012  ψAnSSψSaSS  ψ₁(Sar×SST)
#    555     0.6004    -0.6004  ψAnSaψAnSa  ψ₁(Anc×Sar)
#    556     0.6002    +0.6002       ψAnSa  ψ₁(Anc×SST)
#    557     0.5977    +0.5977      cos(a)  ψ₁(Anc×SST)
#    558     0.5967    +0.5967  cos(ψSaSS)  ψ₁(SST×SST)
#    559     0.5926    -0.5926  sin(ψAnSS)  Anchovy
#    560     0.5897    +0.5897           a  ψ₁(SST×SST)
#    561     0.5893    -0.5893  ψAnSaψAnSS  ψ₁(Anc×Sar)
#    562     0.5892    -0.5892          ss  ψ₁(Anc×Sar)
#    563     0.5847    -0.5847  ψAnSaψSaSS  ψ₁(Sar×SST)
#    564     0.5841    -0.5841     cos(TN)  Sardine
#    565     0.5839    -0.5839     TSψAnSS  ψ₁(Anc×Sar)
#    566     0.5832    -0.5832     TSψSSSS  SST_SIO
#    567     0.5787    -0.5787       ψAnSS  ψ₁(Anc×SST)
#    568     0.5768    -0.5768  ψSaSSψSaSS  ψ₁(Sar×SST)
#    569     0.5739    +0.5739      sψSSSS  ψ₁(Anc×SST)
#    570     0.5682    +0.5682     TSψAnSS  ψ₁(Anc×SST)
#    571     0.5622    +0.5622       ψAnSa  Anchovy
#    572     0.5616    +0.5616     TNψSaSS  ψ₁(Sar×SST)
#    573     0.5564    +0.5564      sin(a)  ψ₁(Anc×SST)
#    574     0.5531    -0.5531      sψSSSS  Sardine
#    575     0.5509    -0.5509        TSTN  ψ₁(Anc×SST)
#    576     0.5469    -0.5469  sin(ψSaSS)  SST_SIO
#    577     0.5468    +0.5468      aψSaSS  Sardine
#    578     0.5443    -0.5443       ψAnSa  ψ₁(Anc×Sar)
#    579     0.5417    -0.5417          as  ψ₁(Anc×SST)
#    580     0.5378    +0.5378          TN  ψ₁(SST×SST)
#    581     0.5377    -0.5377     sin(TN)  ψ₁(Anc×Sar)
#    582     0.5352    +0.5352          TS  ψ₁(Sar×SST)
#    583     0.5333    +0.5333          aa  ψ₁(Sar×SST)
#    584     0.5332    -0.5332      cos(a)  ψ₁(Anc×SST)
#    585     0.5303    -0.5303  ψAnSaψSaSS  SST_SIO
#    586     0.5289    +0.5289     TNψAnSS  ψ₁(Anc×SST)
#    587     0.5246    -0.5246  ψAnSaψAnSS  ψ₁(Sar×SST)
#    588     0.5194    -0.5194  ψAnSSψSSSS  SST_SIO
#    589     0.5189    -0.5189      sin(a)  ψ₁(Sar×SST)
#    590     0.5177    +0.5177      sψAnSa  ψ₁(Anc×SST)
#    591     0.5164    +0.5164      sψSaSS  ψ₁(Sar×SST)
#    592     0.5133    -0.5133     TSψAnSS  ψ₁(Sar×SST)
#    593     0.5094    +0.5094     TNψSSSS  ψ₁(Anc×SST)
#    594     0.5087    +0.5087  ψAnSaψAnSS  ψ₁(Sar×SST)
#    595     0.5080    -0.5080  cos(ψSaSS)  ψ₁(Anc×SST)
#    596     0.5076    +0.5076      sin(a)  Sardine
#    597     0.5064    +0.5064       ψAnSS  Sardine
#    598     0.5049    -0.5049  sin(ψAnSS)  ψ₁(Anc×SST)
#    599     0.5048    +0.5048      sψAnSS  ψ₁(SST×SST)
#    600     0.5044    -0.5044  ψAnSaψAnSa  ψ₁(Sar×SST)
#    601     0.4943    -0.4943  ψAnSSψSaSS  ψ₁(SST×SST)
#    602     0.4931    -0.4931          as  ψ₁(Sar×SST)
#    603     0.4914    +0.4914        TSTS  SST_NP
#    604     0.4884    -0.4884      sψAnSS  ψ₁(Anc×SST)
#    605     0.4873    +0.4873     TNψAnSa  ψ₁(Anc×Sar)
#    606     0.4827    -0.4827       ψSaSS  ψ₁(Anc×Sar)
#    607     0.4822    +0.4822  ψAnSaψAnSS  ψ₁(Sar×SST)
#    608     0.4815    +0.4815     TNψSSSS  ψ₁(Sar×SST)
#    609     0.4783    -0.4783           a  ψ₁(Anc×SST)
#    610     0.4751    +0.4751  cos(ψSSSS)  ψ₁(Anc×SST)
#    611     0.4729    -0.4729  sin(ψSaSS)  ψ₁(Anc×SST)
#    612     0.4703    +0.4703     TSψAnSa  ψ₁(Sar×SST)
#    613     0.4703    +0.4703  ψAnSSψSaSS  ψ₁(Anc×SST)
#    614     0.4682    +0.4682       ψSSSS  ψ₁(SST×SST)
#    615     0.4671    +0.4671  ψAnSaψSaSS  ψ₁(Anc×SST)
#    616     0.4644    +0.4644     TSψSaSS  ψ₁(Anc×Sar)
#    617     0.4628    +0.4628  sin(ψSSSS)  ψ₁(Anc×SST)
#    618     0.4605    +0.4605  cos(ψAnSS)  ψ₁(Anc×Sar)
#    619     0.4592    -0.4592  sin(ψAnSS)  SST_NP
#    620     0.4571    -0.4571  ψAnSSψSaSS  ψ₁(Sar×SST)
#    621     0.4545    -0.4545  ψSaSSψSaSS  ψ₁(Anc×SST)
#    622     0.4505    +0.4505  ψAnSSψSSSS  ψ₁(Anc×SST)
#    623     0.4486    -0.4486       ψSaSS  SST_NP
#    624     0.4478    -0.4478     TSψSSSS  ψ₁(Anc×Sar)
#    625     0.4436    -0.4436  ψAnSaψAnSS  ψ₁(SST×SST)
#    626     0.4424    -0.4424     TNψAnSS  ψ₁(Sar×SST)
#    627     0.4375    +0.4375       ψAnSS  SST_NP
#    628     0.4369    -0.4369       ψSaSS  ψ₁(SST×SST)
#    629     0.4284    -0.4284     TNψAnSS  ψ₁(Anc×SST)
#    630     0.4267    -0.4267      aψAnSa  ψ₁(Anc×SST)
#    631     0.4202    -0.4202  sin(ψAnSS)  ψ₁(Sar×SST)
#    632     0.4167    +0.4167  sin(ψAnSa)  ψ₁(Anc×SST)
#    633     0.4106    +0.4106     TSψAnSS  Anchovy
#    634     0.4105    +0.4105      aψSaSS  ψ₁(Anc×SST)
#    635     0.4101    -0.4101      cos(a)  ψ₁(Anc×Sar)
#    636     0.4089    +0.4089        TSTN  ψ₁(Anc×SST)
#    637     0.4087    -0.4087      aψSSSS  ψ₁(SST×SST)
#    638     0.4082    +0.4082      aψAnSa  ψ₁(Anc×SST)
#    639     0.4074    -0.4074         aTN  ψ₁(Anc×SST)
#    640     0.4067    +0.4067      aψSaSS  ψ₁(Anc×SST)
#    641     0.4038    -0.4038      aψAnSa  Anchovy
#    642     0.4020    +0.4020       ψAnSS  ψ₁(Anc×SST)
#    643     0.3985    +0.3985  ψSaSSψSaSS  ψ₁(Sar×SST)
#    644     0.3946    -0.3946     TSψSSSS  ψ₁(Anc×SST)
#    645     0.3914    +0.3914     TSψSSSS  ψ₁(SST×SST)
#    646     0.3904    +0.3904       ψAnSS  Anchovy
#    647     0.3885    -0.3885      sψSSSS  SST_NP
#    648     0.3858    -0.3858          aa  SST_NP
#    649     0.3796    -0.3796      aψAnSa  SST_SIO
#    650     0.3776    +0.3776  sin(ψSSSS)  ψ₁(Anc×SST)
#    651     0.3714    -0.3714      aψSaSS  ψ₁(Anc×Sar)
#    652     0.3679    -0.3679  ψAnSSψSSSS  ψ₁(Anc×Sar)
#    653     0.3673    -0.3673      aψSaSS  ψ₁(Sar×SST)
#    654     0.3654    -0.3654     TSψAnSS  ψ₁(Anc×SST)
#    655     0.3650    +0.3650  ψAnSaψAnSS  SST_SIO
#    656     0.3598    -0.3598     TNψAnSa  ψ₁(Sar×SST)
#    657     0.3588    -0.3588      sψAnSS  SST_SIO
#    658     0.3545    -0.3545  ψAnSSψSaSS  ψ₁(Sar×SST)
#    659     0.3536    -0.3536  ψAnSaψAnSS  SST_NP
#    660     0.3522    +0.3522      aψAnSS  ψ₁(SST×SST)
#    661     0.3506    -0.3506        TNTN  SST_SIO
#    662     0.3503    +0.3503     TNψSaSS  ψ₁(SST×SST)
#    663     0.3499    -0.3499       ψSSSS  ψ₁(Anc×SST)
#    664     0.3456    +0.3456  ψAnSaψAnSS  ψ₁(Anc×SST)
#    665     0.3450    -0.3450       ψAnSS  ψ₁(Anc×SST)
#    666     0.3434    +0.3434  ψAnSaψSSSS  ψ₁(Sar×SST)
#    667     0.3430    -0.3430      sin(a)  ψ₁(Anc×Sar)
#    668     0.3411    +0.3411     TNψAnSS  ψ₁(Anc×Sar)
#    669     0.3370    +0.3370      cos(s)  ψ₁(Sar×SST)
#    670     0.3330    -0.3330  sin(ψAnSS)  ψ₁(SST×SST)
#    671     0.3327    -0.3327          ss  ψ₁(SST×SST)
#    672     0.3324    +0.3324  ψAnSSψAnSS  ψ₁(Anc×SST)
#    673     0.3300    +0.3300  sin(ψAnSa)  SST_SIO
#    674     0.3275    -0.3275  ψSSSSψSSSS  ψ₁(Anc×Sar)
#    675     0.3271    +0.3271          TN  ψ₁(Sar×SST)
#    676     0.3259    +0.3259       ψAnSS  ψ₁(Anc×Sar)
#    677     0.3228    +0.3228  ψAnSSψSSSS  ψ₁(Anc×Sar)
#    678     0.3190    +0.3190         aTN  ψ₁(SST×SST)
#    679     0.3187    +0.3187     sin(TN)  ψ₁(Anc×SST)
#    680     0.3176    -0.3176       ψAnSa  ψ₁(Sar×SST)
#    681     0.3162    +0.3162       ψAnSS  ψ₁(Anc×SST)
#    682     0.3162    -0.3162  sin(ψAnSS)  SST_NP
#    683     0.3149    -0.3149     TSψSaSS  ψ₁(SST×SST)
#    684     0.3148    -0.3148     TSψAnSS  ψ₁(Sar×SST)
#    685     0.3135    +0.3135  sin(ψSaSS)  ψ₁(Anc×Sar)
#    686     0.3132    +0.3132     cos(TN)  ψ₁(SST×SST)
#    687     0.3079    -0.3079  ψAnSaψSaSS  ψ₁(SST×SST)
#    688     0.3066    +0.3066           a  SST_SIO
#    689     0.3019    -0.3019  ψAnSaψAnSS  ψ₁(Anc×SST)
#    690     0.3014    +0.3014     TSψSaSS  SST_SIO
#    691     0.2998    +0.2998  ψSaSSψSaSS  ψ₁(SST×SST)
#    692     0.2998    +0.2998      sψAnSS  ψ₁(Anc×SST)
#    693     0.2944    +0.2944     TSψSaSS  ψ₁(Anc×Sar)
#    694     0.2939    -0.2939          as  Sardine
#    695     0.2884    -0.2884  sin(ψSaSS)  ψ₁(SST×SST)
#    696     0.2879    -0.2879  ψSaSSψSSSS  SST_NP
#    697     0.2855    +0.2855        TSTN  ψ₁(Sar×SST)
#    698     0.2834    +0.2834     TSψSaSS  Sardine
#    699     0.2824    +0.2824          aa  Anchovy
#    700     0.2823    -0.2823  cos(ψAnSS)  ψ₁(Sar×SST)
#    701     0.2815    +0.2815      sψSSSS  ψ₁(SST×SST)
#    702     0.2778    +0.2778  ψAnSSψSaSS  ψ₁(Sar×SST)
#    703     0.2776    +0.2776          as  ψ₁(Anc×SST)
#    704     0.2770    -0.2770      sψSaSS  ψ₁(SST×SST)
#    705     0.2765    +0.2765  cos(ψSSSS)  ψ₁(Anc×SST)
#    706     0.2752    +0.2752      sψAnSa  ψ₁(SST×SST)
#    707     0.2704    +0.2704          as  ψ₁(SST×SST)
#    708     0.2679    +0.2679          aa  ψ₁(SST×SST)
#    709     0.2666    +0.2666       ψSSSS  ψ₁(Sar×SST)
#    710     0.2660    +0.2660     sin(TN)  ψ₁(Sar×SST)
#    711     0.2627    +0.2627         sTN  ψ₁(SST×SST)
#    712     0.2593    -0.2593  ψSaSSψSaSS  ψ₁(Anc×Sar)
#    713     0.2585    +0.2585  cos(ψSaSS)  ψ₁(Anc×SST)
#    714     0.2585    +0.2585  ψAnSaψSaSS  ψ₁(Anc×SST)
#    715     0.2562    -0.2562           s  ψ₁(SST×SST)
#    716     0.2541    -0.2541          aa  ψ₁(Anc×Sar)
#    717     0.2538    -0.2538          TN  Anchovy
#    718     0.2516    -0.2516      sψSaSS  ψ₁(SST×SST)
#    719     0.2465    +0.2465      aψSaSS  ψ₁(Anc×SST)
#    720     0.2454    -0.2454  cos(ψAnSa)  Sardine
#    721     0.2445    -0.2445       ψAnSa  ψ₁(SST×SST)
#    722     0.2429    +0.2429  ψAnSSψSaSS  ψ₁(Anc×Sar)
#    723     0.2421    -0.2421      aψAnSS  SST_SIO
#    724     0.2401    -0.2401     sin(TN)  SST_NP
#    725     0.2363    +0.2363       ψAnSa  ψ₁(Anc×SST)
#    726     0.2358    -0.2358           s  ψ₁(Sar×SST)
#    727     0.2346    -0.2346     TSψAnSS  SST_SIO
#    728     0.2339    +0.2339      aψSaSS  ψ₁(Anc×SST)
#    729     0.2325    -0.2325         aTS  ψ₁(SST×SST)
#    730     0.2298    -0.2298  ψSaSSψSaSS  Sardine
#    731     0.2269    -0.2269      sψAnSa  ψ₁(Anc×SST)
#    732     0.2265    +0.2265      cos(a)  SST_SIO
#    733     0.2245    +0.2245     TNψAnSa  SST_NP
#    734     0.2232    -0.2232      aψSaSS  SST_SIO
#    735     0.2216    -0.2216  ψAnSaψSaSS  ψ₁(Anc×Sar)
#    736     0.2211    -0.2211      sψSSSS  SST_SIO
#    737     0.2193    -0.2193         aTS  SST_SIO
#    738     0.2182    +0.2182       ψAnSS  ψ₁(Anc×Sar)
#    739     0.2180    +0.2180      sψSaSS  ψ₁(Anc×SST)
#    740     0.2180    +0.2180     TNψAnSa  SST_SIO
#    741     0.2174    +0.2174          as  SST_SIO
#    742     0.2156    -0.2156  sin(ψSaSS)  ψ₁(SST×SST)
#    743     0.2154    +0.2154      cos(s)  ψ₁(Anc×SST)
#    744     0.2151    -0.2151      sin(s)  ψ₁(Sar×SST)
#    745     0.2117    +0.2117          ss  ψ₁(Sar×SST)
#    746     0.2109    +0.2109  ψAnSSψSaSS  ψ₁(SST×SST)
#    747     0.2068    +0.2068      sin(a)  ψ₁(Sar×SST)
#    748     0.2064    -0.2064  cos(ψAnSa)  ψ₁(SST×SST)
#    749     0.2042    +0.2042  ψSSSSψSSSS  ψ₁(Sar×SST)
#    750     0.2038    +0.2038  ψSaSSψSaSS  ψ₁(Anc×SST)
#    751     0.2012    +0.2012     TNψAnSS  SST_SIO
#    752     0.1996    -0.1996  cos(ψAnSS)  ψ₁(SST×SST)
#    753     0.1970    -0.1970       ψAnSS  ψ₁(Sar×SST)
#    754     0.1960    +0.1960      sin(s)  Sardine
#    755     0.1943    -0.1943  ψSaSSψSSSS  SST_SIO
#    756     0.1939    +0.1939      aψAnSS  ψ₁(Sar×SST)
#    757     0.1929    -0.1929  ψAnSSψSSSS  ψ₁(Anc×SST)
#    758     0.1872    +0.1872     TSψSaSS  ψ₁(SST×SST)
#    759     0.1798    -0.1798       ψSaSS  ψ₁(Anc×SST)
#    760     0.1798    -0.1798  ψAnSaψAnSS  ψ₁(Anc×SST)
#    761     0.1790    -0.1790     TNψSSSS  ψ₁(Anc×Sar)
#    762     0.1765    +0.1765     TSψAnSS  SST_NP
#    763     0.1736    -0.1736        TSTN  ψ₁(SST×SST)
#    764     0.1732    +0.1732  ψAnSaψAnSS  Anchovy
#    765     0.1713    +0.1713          ss  ψ₁(Anc×SST)
#    766     0.1689    -0.1689     TNψAnSS  SST_NP
#    767     0.1674    +0.1674  ψAnSaψSaSS  ψ₁(Anc×SST)
#    768     0.1673    -0.1673  ψAnSSψSaSS  SST_SIO
#    769     0.1665    -0.1665       ψSaSS  ψ₁(Sar×SST)
#    770     0.1656    +0.1656      sψSSSS  ψ₁(Sar×SST)
#    771     0.1642    -0.1642        TNTN  SST_NP
#    772     0.1640    -0.1640  ψSaSSψSaSS  ψ₁(Anc×Sar)
#    773     0.1636    -0.1636      sψSaSS  SST_SIO
#    774     0.1615    +0.1615  ψSSSSψSSSS  ψ₁(SST×SST)
#    775     0.1613    -0.1613  ψSaSSψSSSS  ψ₁(SST×SST)
#    776     0.1613    -0.1613          as  ψ₁(Sar×SST)
#    777     0.1606    -0.1606  sin(ψAnSa)  ψ₁(Sar×SST)
#    778     0.1601    +0.1601     TSψAnSa  SST_NP
#    779     0.1558    -0.1558  ψSaSSψSaSS  ψ₁(SST×SST)
#    780     0.1537    +0.1537  ψAnSSψSSSS  ψ₁(SST×SST)
#    781     0.1522    +0.1522     TSψSaSS  ψ₁(Sar×SST)
#    782     0.1518    +0.1518  sin(ψAnSa)  ψ₁(Anc×Sar)
#    783     0.1474    -0.1474  ψAnSSψSaSS  Anchovy
#    784     0.1464    -0.1464      sin(a)  SST_NP
#    785     0.1439    +0.1439  ψSaSSψSaSS  ψ₁(Anc×SST)
#    786     0.1436    +0.1436  ψSaSSψSaSS  ψ₁(SST×SST)
#    787     0.1432    +0.1432      aψSSSS  SST_SIO
#    788     0.1424    +0.1424      aψAnSS  ψ₁(Anc×Sar)
#    789     0.1406    -0.1406      sin(a)  ψ₁(SST×SST)
#    790     0.1385    -0.1385  sin(ψSaSS)  SST_NP
#    791     0.1330    +0.1330  ψAnSaψSaSS  ψ₁(SST×SST)
#    792     0.1326    -0.1326       ψSaSS  SST_SIO
#    793     0.1317    -0.1317          aa  ψ₁(Anc×SST)
#    794     0.1288    -0.1288     TSψAnSS  ψ₁(Anc×SST)
#    795     0.1281    +0.1281     sin(TN)  SST_SIO
#    796     0.1257    +0.1257  ψAnSaψSaSS  Sardine
#    797     0.1255    +0.1255          aa  ψ₁(Anc×SST)
#    798     0.1253    -0.1253         aTS  SST_NP
#    799     0.1235    +0.1235  ψAnSSψSaSS  SST_SIO
#    800     0.1232    +0.1232  ψAnSSψSaSS  ψ₁(SST×SST)
#    801     0.1192    -0.1192  ψAnSSψSSSS  ψ₁(Anc×SST)
#    802     0.1148    +0.1148        TSTS  Anchovy
#    803     0.1130    -0.1130      sψAnSS  ψ₁(Sar×SST)
#    804     0.1085    +0.1085  ψAnSaψSSSS  ψ₁(Anc×Sar)
#    805     0.1068    +0.1068     TSψAnSa  SST_SIO
#    806     0.1033    +0.1033          ss  ψ₁(Anc×SST)
#    807     0.1026    +0.1026  ψAnSSψSaSS  ψ₁(SST×SST)
#    808     0.0997    +0.0997     TSψSaSS  Anchovy
#    809     0.0997    +0.0997  ψSSSSψSSSS  ψ₁(Sar×SST)
#    810     0.0992    -0.0992         aTS  ψ₁(Sar×SST)
#    811     0.0985    -0.0985  ψSaSSψSaSS  ψ₁(Anc×SST)
#    812     0.0984    -0.0984  sin(ψAnSS)  ψ₁(Sar×SST)
#    813     0.0925    -0.0925      sψSaSS  Sardine
#    814     0.0925    -0.0925  ψAnSaψAnSa  ψ₁(SST×SST)
#    815     0.0924    -0.0924  ψAnSSψSaSS  ψ₁(Anc×Sar)
#    816     0.0872    -0.0872  ψAnSaψSSSS  ψ₁(SST×SST)
#    817     0.0865    -0.0865       ψAnSS  SST_SIO
#    818     0.0862    -0.0862           1  ψ₁(Anc×SST)
#    819     0.0859    +0.0859           1  ψ₁(Anc×SST)
#    820     0.0849    -0.0849  ψAnSSψSaSS  ψ₁(Sar×SST)
#    821     0.0838    -0.0838     TSψAnSa  ψ₁(Sar×SST)
#    822     0.0823    -0.0823      aψAnSS  ψ₁(Anc×SST)
#    823     0.0815    +0.0815        TSTN  ψ₁(Anc×Sar)
#    824     0.0798    +0.0798     TNψSSSS  ψ₁(Sar×SST)
#    825     0.0776    +0.0776  sin(ψSSSS)  ψ₁(Anc×Sar)
#    826     0.0759    +0.0759  sin(ψAnSS)  ψ₁(Anc×SST)
#    827     0.0737    -0.0737     TSψAnSa  ψ₁(SST×SST)
#    828     0.0719    -0.0719  ψSaSSψSaSS  ψ₁(Sar×SST)
#    829     0.0709    -0.0709      aψAnSa  ψ₁(Anc×Sar)
#    830     0.0687    +0.0687      sin(s)  ψ₁(SST×SST)
#    831     0.0679    +0.0679  ψAnSSψAnSS  ψ₁(SST×SST)
#    832     0.0639    -0.0639  ψAnSSψSaSS  ψ₁(Anc×SST)
#    833     0.0604    -0.0604  cos(ψSSSS)  ψ₁(Sar×SST)
#    834     0.0577    +0.0577  ψAnSaψSaSS  Sardine
#    835     0.0557    +0.0557      sψSSSS  ψ₁(Anc×Sar)
#    836     0.0549    +0.0549  sin(ψSaSS)  ψ₁(Anc×Sar)
#    837     0.0538    -0.0538  sin(ψSaSS)  ψ₁(Anc×SST)
#    838     0.0525    -0.0525     cos(TN)  ψ₁(Anc×SST)
#    839     0.0510    +0.0510     TNψAnSa  ψ₁(SST×SST)
#    840     0.0492    +0.0492  ψAnSaψSSSS  SST_NP
#    841     0.0489    +0.0489      aψSSSS  ψ₁(Anc×SST)
#    842     0.0478    -0.0478      sψSaSS  ψ₁(Anc×SST)
#    843     0.0450    -0.0450           a  Sardine
#    844     0.0387    -0.0387         aTN  SST_NP
#    845     0.0385    -0.0385     TSψSaSS  Anchovy
#    846     0.0380    -0.0380  cos(ψSSSS)  ψ₁(SST×SST)
#    847     0.0375    +0.0375      sψSaSS  Sardine
#    848     0.0367    +0.0367  sin(ψAnSS)  Sardine
#    849     0.0358    +0.0358     TNψSSSS  ψ₁(Anc×SST)
#    850     0.0343    +0.0343  ψSSSSψSSSS  ψ₁(Anc×SST)
#    851     0.0330    -0.0330  ψAnSSψAnSS  ψ₁(Anc×SST)
#    852     0.0316    +0.0316      aψSaSS  ψ₁(SST×SST)
#    853     0.0309    -0.0309  ψAnSaψAnSS  ψ₁(SST×SST)
#    854     0.0305    +0.0305          aa  SST_SIO
#    855     0.0179    +0.0179      aψAnSS  ψ₁(Sar×SST)
#    856     0.0141    -0.0141  ψAnSaψSaSS  ψ₁(Sar×SST)
#    857     0.0122    -0.0122          as  ψ₁(Anc×Sar)
#    858     0.0081    +0.0081  ψSSSSψSSSS  ψ₁(Anc×SST)
#    859     0.0079    -0.0079      sψSaSS  SST_NP
#    860     0.0051    +0.0051     TSψAnSa  ψ₁(Anc×Sar)
#
# ══════════════════════════════════════════════════════════════
#   AUGMENTED  —  Discovered equations  x(t+1) = F(x(t))
# ══════════════════════════════════════════════════════════════
#   Anchovy(t+1) = +10.8232·1 +1.7411·ψSaSS -1.8829·ψAnSaψAnSa -2.5972·ψSaSSψSaSS -2.3766·sin(ψSaSS) -4.7497·cos(ψAnSa) -6.2297·cos(ψSaSS)
#   Sardine(t+1) = 0
#   SST_SIO(t+1) = +1.8513·cos(ψAnSS) -1.6724·cos(ψAnSS)
#   SST_NP(t+1) = +16.9672·1 -7.1295·ψSSSSψSSSS -17.2736·cos(ψSSSS)
#   ψ₁(Anc×Sar)(t+1) = 0
#   ψ₁(Anc×SST)(t+1) = 0
#   ψ₁(Anc×SST)(t+1) = 0
#   ψ₁(Sar×SST)(t+1) = 0
#   ψ₁(Sar×SST)(t+1) = 0
#   ψ₁(SST×SST)(t+1) = 0
#
#   R²: Anchovy: 0.143   Sardine: -0.000   SST_SIO: 0.305   SST_NP: 0.349   ψ₁(Anc×Sar): -0.000   ψ₁(Anc×SST): -0.000   ψ₁(Anc×SST): -0.000   ψ₁(Sar×SST): -0.000   ψ₁(Sar×SST): -0.000   ψ₁(SST×SST): -0.000
#
# ──────────────────────────────────────────────────
#   Variable        Baseline   Augmented         Δ
#   ──────────────────────────────────────────────
#   Anchovy            0.157       0.143  ▽ -0.014
#   Sardine            0.134      -0.000  ▽ -0.134
#   SST_SIO            0.757       0.305  ▽ -0.452
#   SST_NP             0.646       0.349  ▽ -0.297

# %%
# ── Bar chart ──────────────────────────────────────────────────────────────
x = np.arange(4);  width = 0.35
fig, ax = plt.subplots(figsize=(9, 4))
b1 = ax.bar(x - width/2, r2_base, width,
            label=f'Baseline (top_pct={TOP_PCT_BASE}%)', color='steelblue', alpha=0.85)
b2 = ax.bar(x + width/2, r2_aug[:4], width,
            label=f'Augmented (top_pct={TOP_PCT_AUG}%)', color='darkorange', alpha=0.85)
for bars, vals in [(b1, r2_base), (b2, r2_aug[:4])]:
    for bar, v in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.02,
                f'{v:.2f}', ha='center', va='bottom', fontsize=9)
ax.set_xticks(x);  ax.set_xticklabels(obs_long, fontsize=11)
ax.set_ylabel('One-step-ahead R²', fontsize=11)
ax.set_title('SINDy R²: baseline vs SHREC-augmented', fontsize=12, fontweight='bold')
ax.axhline(0, color='k', lw=0.8, ls='--')
ax.legend(fontsize=10);  ax.set_ylim(-0.2, 1.05)
plt.tight_layout()
plt.show()

# %%
# ── Trajectory plots ───────────────────────────────────────────────────────
t_plot_base = years[1:]    # 77 steps  (full series)
t_plot_aug  = years[3:]    # 75 steps  (trimmed for SHREC)
colors_obs = ['steelblue', 'tomato', 'seagreen', 'darkorange']

fig, axes = plt.subplots(4, 2, figsize=(14, 14))
for i, (vname, c) in enumerate(zip(obs_long, colors_obs)):
    for j, (pred, Xtp1, t_plot, lab, col) in enumerate([
        (pred_base, Xtp1_base, t_plot_base, f'Baseline  (top_pct={TOP_PCT_BASE}%)',  'steelblue'),
        (pred_aug,  Xtp1_aug,  t_plot_aug,  f'Augmented (top_pct={TOP_PCT_AUG}%)', 'darkorange'),
    ]):
        ax = axes[i, j]
        r2v = r2_base[i] if j == 0 else r2_aug[i]
        ax.plot(t_plot, Xtp1[:, i], color='k', lw=1.8, label='Observed')
        ax.plot(t_plot, pred[:, i], color=col, lw=1.5, ls='--', label=f'SINDy')
        ax.set_title(f'{vname} — {lab}  (R²={r2v:.3f})', fontsize=9)
        ax.set_xlabel('Year');  ax.legend(fontsize=8);  ax.grid(alpha=0.3)
plt.suptitle('One-step-ahead: Baseline vs SHREC-augmented SINDy',
             fontsize=12, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %%
# ── Heatmaps ───────────────────────────────────────────────────────────────
for label, Xi, feat, lamb, row_labels, top_pct in [
    ("BASELINE",  Xi_base, feat_base, lamb_base,
     [f'{v}(t+1)' for v in obs_long], TOP_PCT_BASE),
    ("AUGMENTED", Xi_aug,  feat_aug,  lamb_aug,
     [f'{v}(t+1)' for v in long_aug], TOP_PCT_AUG),
]:
    vmax = np.abs(Xi).max()
    if vmax < 1e-10:
        print(f'⚠ {label}: all zero — raise TOP_PCT and re-run.');  continue
    n_rows = Xi.shape[1]
    fig, ax = plt.subplots(figsize=(max(12, len(feat) * 0.55), max(4, n_rows * 0.7)))
    im = ax.imshow(Xi.T, aspect='auto', cmap='RdBu_r', vmin=-vmax, vmax=vmax)
    ax.set_xticks(range(len(feat)))
    ax.set_xticklabels(feat, rotation=45, ha='right', fontsize=9)
    ax.set_yticks(range(n_rows));  ax.set_yticklabels(row_labels, fontsize=10)
    for i in range(n_rows):
        for j in range(len(feat)):
            v = Xi[j, i]
            if abs(v) > 1e-10:
                ax.text(j, i, f'{v:.2f}', ha='center', va='center',
                        fontsize=8, color='white' if abs(v) > 0.4 * vmax else 'black')
    plt.colorbar(im, ax=ax, label='Coefficient value')
    n_active = int(np.sum(np.abs(Xi) > 1e-10))
    ax.set_title(f'SINDy Ξ — {label}  (top_pct={top_pct}%,  λ={lamb:.4f},  {n_active} active terms)',
                 fontsize=11)
    plt.tight_layout()
    plt.show()
